# %%
from keras.preprocessing.image import ImageDataGenerator
# image settings

image_size=64

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=40,
    width_shift_range=.2,
    height_shift_range=.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode="nearest"
    )

test_datagen = ImageDataGenerator(rescale=1./255)

# reading image

training_data = train_datagen.flow_from_directory(
    "Tomato_Dataset\\train_orj",
    target_size=(image_size,image_size),
    batch_size=64,
    class_mode='categorical' 
)

# print(training_data.class_indices)

testing_data = test_datagen.flow_from_directory(
    "Tomato_Dataset\\val",
    target_size=(image_size,image_size),
    batch_size=64,
    class_mode='categorical'
)

# print(testing_data.image_shape)
# print(testing_data.)
# Out:
# Found 10000 images belonging to 10 classes.
# Found 1000 images belonging to 10 classes.

# %%
from keras.preprocessing.image import ImageDataGenerator
# image settings

image_size=64

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=40,
    width_shift_range=.2,
    height_shift_range=.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode="nearest"
    )

test_datagen = ImageDataGenerator(rescale=1./255)

# reading image

training_data = train_datagen.flow_from_directory(
    "Tomato_Dataset\\train_orj",
    target_size=(image_size,image_size),
    batch_size=64,
    class_mode='categorical' 
)

# print(training_data.class_indices)

testing_data = test_datagen.flow_from_directory(
    "Tomato_Dataset\\val",
    target_size=(image_size,image_size),
    batch_size=64,
    class_mode='categorical'
)

# print(testing_data.image_shape)
# print(testing_data.)
# Out:
# Found 10000 images belonging to 10 classes.
# Found 1000 images belonging to 10 classes.

# %%
# model

from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Dropout

model = Sequential()
model.add(Conv2D(32,(3,3),activation="relu", input_shape =(image_size,image_size,3)))
model.add(Conv2D(32,(3,3),activation="relu"))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64,(3,3),activation="relu"))
model.add(Conv2D(64,(3,3),activation="relu"))
model.add(MaxPooling2D(2,2))


model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(512,activation = "relu"))
model.add(Dense(10,activation = "softmax"))

model.compile(optimizer="adam",loss="categorical_crossentropy",metrics=["acc"])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 62, 62, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 60, 60, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 30, 30, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 26, 26, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 13, 13, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 10816)             0
#
#  dropout (Dropout)           (None, 10816)             0
#
#  dense (Dense)               (None, 512)               5538304
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 5,609,002
# Trainable params: 5,609,002
# Non-trainable params: 0
# _________________________________________________________________

# %%
# model

from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Dropout

model = Sequential()
model.add(Conv2D(32,(3,3),activation="relu", input_shape =(image_size,image_size,3)))
model.add(Conv2D(32,(3,3),activation="relu"))
model.add(MaxPooling2D(2,2))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64,(3,3),activation="relu"))
model.add(Conv2D(64,(3,3),activation="relu"))
model.add(MaxPooling2D(2,2))


model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(512,activation = "relu"))
model.add(Dense(10,activation = "softmax"))

model.compile(optimizer="adam",loss="categorical_crossentropy",metrics=["acc"])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 62, 62, 32)        896
#
#  conv2d_5 (Conv2D)           (None, 60, 60, 32)        9248
#
#  max_pooling2d_2 (MaxPooling  (None, 30, 30, 32)       0
#  2D)
#
#  max_pooling2d_3 (MaxPooling  (None, 15, 15, 32)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 13, 13, 64)        18496
#
#  conv2d_7 (Conv2D)           (None, 11, 11, 64)        36928
#
#  max_pooling2d_4 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 1600)              0
#
#  dropout_1 (Dropout)         (None, 1600)              0
#
#  dense_2 (Dense)             (None, 512)               819712
#
#  dense_3 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 890,410
# Trainable params: 890,410
# Non-trainable params: 0
# _________________________________________________________________

# %%
# model

from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Dropout

model = Sequential()
model.add(Conv2D(32,(3,3),activation="relu", input_shape =(image_size,image_size,3)))
model.add(Conv2D(32,(3,3),activation="relu"))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64,(3,3),activation="relu"))
model.add(Conv2D(64,(3,3),activation="relu"))
model.add(MaxPooling2D(2,2))


model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(512,activation = "relu"))
model.add(Dense(10,activation = "softmax"))

model.compile(optimizer="adam",loss="categorical_crossentropy",metrics=["acc"])

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 62, 62, 32)        896
#
#  conv2d_9 (Conv2D)           (None, 60, 60, 32)        9248
#
#  max_pooling2d_5 (MaxPooling  (None, 30, 30, 32)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 28, 28, 64)        18496
#
#  conv2d_11 (Conv2D)          (None, 26, 26, 64)        36928
#
#  max_pooling2d_6 (MaxPooling  (None, 13, 13, 64)       0
#  2D)
#
#  flatten_2 (Flatten)         (None, 10816)             0
#
#  dropout_2 (Dropout)         (None, 10816)             0
#
#  dense_4 (Dense)             (None, 512)               5538304
#
#  dense_5 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 5,609,002
# Trainable params: 5,609,002
# Non-trainable params: 0
# _________________________________________________________________

# %%
# model

from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Dropout

model = Sequential()
model.add(Conv2D(32,(3,3),activation="relu", input_shape =(image_size,image_size,3)))
model.add(Conv2D(32,(3,3),activation="relu"))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64,(3,3),activation="relu"))
model.add(Conv2D(64,(3,3),activation="relu"))
model.add(MaxPooling2D(2,2))


model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(512,activation = "relu"))
model.add(Dense(512,activation = "relu"))
model.add(Dense(10,activation = "softmax"))

model.compile(optimizer="adam",loss="categorical_crossentropy",metrics=["acc"])

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 62, 62, 32)        896
#
#  conv2d_13 (Conv2D)          (None, 60, 60, 32)        9248
#
#  max_pooling2d_7 (MaxPooling  (None, 30, 30, 32)       0
#  2D)
#
#  conv2d_14 (Conv2D)          (None, 28, 28, 64)        18496
#
#  conv2d_15 (Conv2D)          (None, 26, 26, 64)        36928
#
#  max_pooling2d_8 (MaxPooling  (None, 13, 13, 64)       0
#  2D)
#
#  flatten_3 (Flatten)         (None, 10816)             0
#
#  dropout_3 (Dropout)         (None, 10816)             0
#
#  dense_6 (Dense)             (None, 512)               5538304
#
#  dense_7 (Dense)             (None, 512)               262656
#
#  dense_8 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 5,871,658
# Trainable params: 5,871,658
# Non-trainable params: 0
# _________________________________________________________________

# %%
# model

from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Dropout

model = Sequential()
model.add(Conv2D(32,(3,3),activation="relu", input_shape =(image_size,image_size,3)))
model.add(Conv2D(32,(3,3),activation="relu"))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64,(3,3),activation="relu"))
model.add(Conv2D(64,(3,3),activation="relu"))
model.add(MaxPooling2D(2,2))


model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(512,activation = "relu"))
model.add(Dense(10,activation = "softmax"))

model.compile(optimizer="adam",loss="categorical_crossentropy",metrics=["acc"])

model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_16 (Conv2D)          (None, 62, 62, 32)        896
#
#  conv2d_17 (Conv2D)          (None, 60, 60, 32)        9248
#
#  max_pooling2d_9 (MaxPooling  (None, 30, 30, 32)       0
#  2D)
#
#  conv2d_18 (Conv2D)          (None, 28, 28, 64)        18496
#
#  conv2d_19 (Conv2D)          (None, 26, 26, 64)        36928
#
#  max_pooling2d_10 (MaxPoolin  (None, 13, 13, 64)       0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 10816)             0
#
#  dropout_4 (Dropout)         (None, 10816)             0
#
#  dense_9 (Dense)             (None, 512)               5538304
#
#  dense_10 (Dense)            (None, 10)                5130
#
# =================================================================
# Total params: 5,609,002
# Trainable params: 5,609,002
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit_generator(
        training_data,
        steps_per_epoch=156,
        epochs=50,
        validation_data=testing_data,
        validation_steps=15)
# Out:
# <ipython-input-8-5447e1a1c48d>:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# Epoch 1/50
# 156/156 [==============================] - 42s 228ms/step - loss: 1.6869 - acc: 0.3834 - val_loss: 1.0606 - val_acc: 0.6396
# Epoch 2/50
# 156/156 [==============================] - 18s 111ms/step - loss: 0.9790 - acc: 0.6459 - val_loss: 2.2397 - val_acc: 0.4865
# Epoch 3/50
# 156/156 [==============================] - 17s 111ms/step - loss: 0.7540 - acc: 0.7341 - val_loss: 1.7261 - val_acc: 0.5719
# Epoch 4/50
# 156/156 [==============================] - 21s 133ms/step - loss: 0.6192 - acc: 0.7848 - val_loss: 1.8533 - val_acc: 0.5688
# Epoch 5/50
# 156/156 [==============================] - 21s 133ms/step - loss: 0.5569 - acc: 0.8021 - val_loss: 1.0492 - val_acc: 0.7052
# Epoch 6/50
# 156/156 [==============================] - 23s 148ms/step - loss: 0.5300 - acc: 0.8158 - val_loss: 1.4038 - val_acc: 0.6531
# Epoch 7/50
# 156/156 [==============================] - 21s 133ms/step - loss: 0.4554 - acc: 0.8430 - val_loss: 1.8754 - val_acc: 0.6115
# Epoch 8/50
# 156/156 [==============================] - 19s 118ms/step - loss: 0.4238 - acc: 0.8469 - val_loss: 2.0057 - val_acc: 0.5927
# Epoch 9/50
# 156/156 [==============================] - 18s 115ms/step - loss: 0.4052 - acc: 0.8589 - val_loss: 1.6287 - val_acc: 0.6417
# Epoch 10/50
# 156/156 [==============================] - 18s 117ms/step - loss: 0.3654 - acc: 0.8721 - val_loss: 1.1098 - val_acc: 0.7385
# Epoch 11/50
# 156/156 [==============================] - 19s 124ms/step - loss: 0.3342 - acc: 0.8863 - val_loss: 1.4770 - val_acc: 0.6812
# Epoch 12/50
# 156/156 [==============================] - 18s 116ms/step - loss: 0.3329 - acc: 0.8821 - val_loss: 1.4235 - val_acc: 0.6844
# Epoch 13/50
# 156/156 [==============================] - 19s 122ms/step - loss: 0.3319 - acc: 0.8827 - val_loss: 1.4762 - val_acc: 0.6917
# Epoch 14/50
# 156/156 [==============================] - 18s 113ms/step - loss: 0.2992 - acc: 0.8912 - val_loss: 1.7253 - val_acc: 0.6729
# Epoch 15/50
# 156/156 [==============================] - 19s 119ms/step - loss: 0.2996 - acc: 0.8936 - val_loss: 1.3007 - val_acc: 0.7094
# Epoch 16/50
# 156/156 [==============================] - 18s 112ms/step - loss: 0.2781 - acc: 0.8997 - val_loss: 0.9980 - val_acc: 0.7625
# Epoch 17/50
# 156/156 [==============================] - 17s 110ms/step - loss: 0.2743 - acc: 0.9063 - val_loss: 0.8718 - val_acc: 0.7823
# Epoch 18/50
# 156/156 [==============================] - 18s 114ms/step - loss: 0.2712 - acc: 0.9053 - val_loss: 2.9077 - val_acc: 0.5958
# Epoch 19/50
# 156/156 [==============================] - 17s 111ms/step - loss: 0.2543 - acc: 0.9082 - val_loss: 0.6181 - val_acc: 0.8458
# Epoch 20/50
# 156/156 [==============================] - 17s 111ms/step - loss: 0.2454 - acc: 0.9123 - val_loss: 0.6845 - val_acc: 0.8292
# Epoch 21/50
# 156/156 [==============================] - 18s 112ms/step - loss: 0.2361 - acc: 0.9178 - val_loss: 1.1827 - val_acc: 0.7344
# Epoch 22/50
# 156/156 [==============================] - 17s 111ms/step - loss: 0.2650 - acc: 0.9053 - val_loss: 0.7268 - val_acc: 0.7927
# Epoch 23/50
# 156/156 [==============================] - 17s 110ms/step - loss: 0.2442 - acc: 0.9115 - val_loss: 0.7028 - val_acc: 0.8115
# Epoch 24/50
# 156/156 [==============================] - 18s 112ms/step - loss: 0.2360 - acc: 0.9169 - val_loss: 0.8460 - val_acc: 0.7979
# Epoch 25/50
# 156/156 [==============================] - 17s 111ms/step - loss: 0.2308 - acc: 0.9161 - val_loss: 1.6980 - val_acc: 0.6771
# Epoch 26/50
# 156/156 [==============================] - 17s 111ms/step - loss: 0.1801 - acc: 0.9348 - val_loss: 0.6349 - val_acc: 0.8385
# Epoch 27/50
# 156/156 [==============================] - 18s 113ms/step - loss: 0.2012 - acc: 0.9310 - val_loss: 0.3751 - val_acc: 0.8740
# Epoch 28/50
# 156/156 [==============================] - 17s 110ms/step - loss: 0.1987 - acc: 0.9314 - val_loss: 0.7759 - val_acc: 0.8042
# Epoch 29/50
# 156/156 [==============================] - 20s 126ms/step - loss: 0.2175 - acc: 0.9251 - val_loss: 1.1167 - val_acc: 0.7812
# Epoch 30/50
# 156/156 [==============================] - 20s 127ms/step - loss: 0.1845 - acc: 0.9332 - val_loss: 1.0541 - val_acc: 0.7937
# Epoch 31/50
# 156/156 [==============================] - 19s 124ms/step - loss: 0.1922 - acc: 0.9312 - val_loss: 1.0064 - val_acc: 0.7771
# Epoch 32/50
# 156/156 [==============================] - 19s 120ms/step - loss: 0.1680 - acc: 0.9418 - val_loss: 0.8304 - val_acc: 0.8292
# Epoch 33/50
# 156/156 [==============================] - 19s 120ms/step - loss: 0.1975 - acc: 0.9308 - val_loss: 1.0128 - val_acc: 0.7573
# Epoch 34/50
# 156/156 [==============================] - 18s 113ms/step - loss: 0.2118 - acc: 0.9241 - val_loss: 0.4526 - val_acc: 0.8667
# Epoch 35/50
# 156/156 [==============================] - 17s 111ms/step - loss: 0.1711 - acc: 0.9387 - val_loss: 1.2665 - val_acc: 0.7312
# Epoch 36/50
# 156/156 [==============================] - 17s 109ms/step - loss: 0.1831 - acc: 0.9361 - val_loss: 1.0295 - val_acc: 0.7729
# Epoch 37/50
# 156/156 [==============================] - 17s 108ms/step - loss: 0.1789 - acc: 0.9361 - val_loss: 0.7540 - val_acc: 0.8240
# Epoch 38/50
# 156/156 [==============================] - 17s 109ms/step - loss: 0.1814 - acc: 0.9349 - val_loss: 0.6213 - val_acc: 0.8219
# Epoch 39/50
# 156/156 [==============================] - 17s 109ms/step - loss: 0.1490 - acc: 0.9479 - val_loss: 1.3075 - val_acc: 0.7635
# Epoch 40/50
# 156/156 [==============================] - 17s 108ms/step - loss: 0.1730 - acc: 0.9394 - val_loss: 0.4067 - val_acc: 0.8802
# Epoch 41/50
# 156/156 [==============================] - 17s 109ms/step - loss: 0.1562 - acc: 0.9463 - val_loss: 0.3318 - val_acc: 0.9000
# Epoch 42/50
# 156/156 [==============================] - 17s 110ms/step - loss: 0.1414 - acc: 0.9506 - val_loss: 0.4053 - val_acc: 0.8813
# Epoch 43/50
# 156/156 [==============================] - 17s 108ms/step - loss: 0.1584 - acc: 0.9443 - val_loss: 0.4513 - val_acc: 0.8833
# Epoch 44/50
# 156/156 [==============================] - 17s 109ms/step - loss: 0.1398 - acc: 0.9512 - val_loss: 0.8806 - val_acc: 0.8125
# Epoch 45/50
# 156/156 [==============================] - 17s 107ms/step - loss: 0.1421 - acc: 0.9499 - val_loss: 0.9885 - val_acc: 0.7917
# Epoch 46/50
# 156/156 [==============================] - 17s 110ms/step - loss: 0.1621 - acc: 0.9439 - val_loss: 0.9314 - val_acc: 0.7990
# Epoch 47/50
# 156/156 [==============================] - 17s 108ms/step - loss: 0.1547 - acc: 0.9460 - val_loss: 0.7172 - val_acc: 0.8427
# Epoch 48/50
# 156/156 [==============================] - 17s 109ms/step - loss: 0.1398 - acc: 0.9504 - val_loss: 0.6317 - val_acc: 0.8458
# Epoch 49/50
# 156/156 [==============================] - 17s 108ms/step - loss: 0.1432 - acc: 0.9502 - val_loss: 0.9289 - val_acc: 0.7927
# Epoch 50/50
# 156/156 [==============================] - 17s 111ms/step - loss: 0.1477 - acc: 0.9490 - val_loss: 0.8823 - val_acc: 0.8177

# %%
import matplotlib.pyplot as plt

acc_original=history.history["acc"]
val_acc_original=history.history["val_acc"]
loss_original=history.history["loss"]
val_loss_original=history.history["val_loss"]

epochs=range(1,len(acc_original)+1)
val_epochs=range(1,len(val_acc_original)+1)


sizeplt=plt.figure()
sizeplt.set_figwidth(16)
sizeplt.set_figheight(6)

plt.plot(epochs,acc_original,'mo',label="Eğitim başarımı(original)")
plt.plot(val_epochs,val_acc_original,'m--',label="Doğrulama başarımı(original)")
plt.title("Eğitim ve Doğrulama başarımı")
plt.legend()
plt.figure()


sizeplt=plt.figure()
sizeplt.set_figwidth(16)
sizeplt.set_figheight(6)

plt.plot(epochs,loss_original,'ko',label="Eğitim kaybı(original)")
plt.plot(val_epochs,val_loss_original,'m--',label="Doğrulama kaybı(original)")
plt.title("Eğitim ve Doğrulama kaybı")
plt.legend()

plt.show()

# %%
# model

from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Dropout

model = Sequential()
model.add(Conv2D(64,(3,3),activation="relu", input_shape =(image_size,image_size,3)))
model.add(Conv2D(64,(3,3),activation="relu"))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128,(3,3),activation="relu"))
model.add(Conv2D(128,(3,3),activation="relu"))
model.add(MaxPooling2D(2,2))


model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(512,activation = "relu"))
model.add(Dense(10,activation = "softmax"))

model.compile(optimizer="adam",loss="categorical_crossentropy",metrics=["acc"])

model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_20 (Conv2D)          (None, 62, 62, 64)        1792
#
#  conv2d_21 (Conv2D)          (None, 60, 60, 64)        36928
#
#  max_pooling2d_11 (MaxPoolin  (None, 30, 30, 64)       0
#  g2D)
#
#  conv2d_22 (Conv2D)          (None, 28, 28, 128)       73856
#
#  conv2d_23 (Conv2D)          (None, 26, 26, 128)       147584
#
#  max_pooling2d_12 (MaxPoolin  (None, 13, 13, 128)      0
#  g2D)
#
#  flatten_5 (Flatten)         (None, 21632)             0
#
#  dropout_5 (Dropout)         (None, 21632)             0
#
#  dense_11 (Dense)            (None, 512)               11076096
#
#  dense_12 (Dense)            (None, 10)                5130
#
# =================================================================
# Total params: 11,341,386
# Trainable params: 11,341,386
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit_generator(
        training_data,
        steps_per_epoch=156,
        epochs=50,
        validation_data=testing_data,
        validation_steps=15)
# Out:
# Epoch 1/50
# <ipython-input-11-5447e1a1c48d>:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# 156/156 [==============================] - 40s 233ms/step - loss: 1.6784 - acc: 0.3883 - val_loss: 1.2712 - val_acc: 0.5781
# Epoch 2/50
# 156/156 [==============================] - 35s 223ms/step - loss: 0.9002 - acc: 0.6788 - val_loss: 1.4944 - val_acc: 0.5656
# Epoch 3/50
# 156/156 [==============================] - 35s 223ms/step - loss: 0.6977 - acc: 0.7521 - val_loss: 1.1567 - val_acc: 0.6708
# Epoch 4/50
# 156/156 [==============================] - 35s 223ms/step - loss: 0.6099 - acc: 0.7828 - val_loss: 0.9449 - val_acc: 0.7094
# Epoch 5/50
# 156/156 [==============================] - 35s 223ms/step - loss: 0.5444 - acc: 0.8062 - val_loss: 0.9494 - val_acc: 0.7000
# Epoch 6/50
# 156/156 [==============================] - 36s 233ms/step - loss: 0.4473 - acc: 0.8385 - val_loss: 1.3574 - val_acc: 0.6823
# Epoch 7/50
# 156/156 [==============================] - 39s 248ms/step - loss: 0.4455 - acc: 0.8395 - val_loss: 0.8324 - val_acc: 0.7688
# Epoch 8/50
# 156/156 [==============================] - 36s 229ms/step - loss: 0.3910 - acc: 0.8585 - val_loss: 0.7987 - val_acc: 0.8000
# Epoch 9/50
# 156/156 [==============================] - 35s 225ms/step - loss: 0.3795 - acc: 0.8640 - val_loss: 1.4639 - val_acc: 0.6687
# Epoch 10/50
# 156/156 [==============================] - 35s 224ms/step - loss: 0.3787 - acc: 0.8662 - val_loss: 0.9581 - val_acc: 0.7458
# Epoch 11/50
# 156/156 [==============================] - 35s 224ms/step - loss: 0.3352 - acc: 0.8793 - val_loss: 0.5007 - val_acc: 0.8427
# Epoch 12/50
# 156/156 [==============================] - 36s 229ms/step - loss: 0.3402 - acc: 0.8783 - val_loss: 1.2484 - val_acc: 0.6885
# Epoch 13/50
# 156/156 [==============================] - 36s 231ms/step - loss: 0.2888 - acc: 0.9014 - val_loss: 0.8994 - val_acc: 0.7656
# Epoch 14/50
# 156/156 [==============================] - 36s 227ms/step - loss: 0.2589 - acc: 0.9084 - val_loss: 0.8947 - val_acc: 0.7677
# Epoch 15/50
# 156/156 [==============================] - 35s 222ms/step - loss: 0.2736 - acc: 0.9015 - val_loss: 0.8956 - val_acc: 0.7875
# Epoch 16/50
# 156/156 [==============================] - 35s 222ms/step - loss: 0.2633 - acc: 0.9056 - val_loss: 0.7047 - val_acc: 0.7833
# Epoch 17/50
# 156/156 [==============================] - 35s 222ms/step - loss: 0.2475 - acc: 0.9124 - val_loss: 1.1607 - val_acc: 0.7365
# Epoch 18/50
# 156/156 [==============================] - 26s 166ms/step - loss: 0.2493 - acc: 0.9117 - val_loss: 0.6568 - val_acc: 0.8323
# Epoch 19/50
# 156/156 [==============================] - 35s 223ms/step - loss: 0.2174 - acc: 0.9238 - val_loss: 0.8891 - val_acc: 0.8042
# Epoch 20/50
# 156/156 [==============================] - 36s 227ms/step - loss: 0.2321 - acc: 0.9174 - val_loss: 1.1155 - val_acc: 0.7698
# Epoch 21/50
# 156/156 [==============================] - 36s 231ms/step - loss: 0.2334 - acc: 0.9192 - val_loss: 0.7430 - val_acc: 0.8104
# Epoch 22/50
# 156/156 [==============================] - 33s 208ms/step - loss: 0.2340 - acc: 0.9180 - val_loss: 0.4197 - val_acc: 0.8719
# Epoch 23/50
# 156/156 [==============================] - 35s 220ms/step - loss: 0.1915 - acc: 0.9305 - val_loss: 0.4091 - val_acc: 0.8813
# Epoch 24/50
# 156/156 [==============================] - 33s 213ms/step - loss: 0.2248 - acc: 0.9221 - val_loss: 0.4211 - val_acc: 0.8667
# Epoch 25/50
# 156/156 [==============================] - 23s 148ms/step - loss: 0.1878 - acc: 0.9340 - val_loss: 0.4761 - val_acc: 0.8438
# Epoch 26/50
# 156/156 [==============================] - 22s 142ms/step - loss: 0.1898 - acc: 0.9314 - val_loss: 0.5097 - val_acc: 0.8677
# Epoch 27/50
# 156/156 [==============================] - 24s 153ms/step - loss: 0.1905 - acc: 0.9322 - val_loss: 0.4948 - val_acc: 0.8625
# Epoch 28/50
# 156/156 [==============================] - 24s 155ms/step - loss: 0.1917 - acc: 0.9348 - val_loss: 0.4018 - val_acc: 0.8698
# Epoch 29/50
# 156/156 [==============================] - 30s 195ms/step - loss: 0.1914 - acc: 0.9319 - val_loss: 0.4781 - val_acc: 0.8583
# Epoch 30/50
# 156/156 [==============================] - 18s 117ms/step - loss: 0.1966 - acc: 0.9302 - val_loss: 0.3786 - val_acc: 0.8948
# Epoch 31/50
# 156/156 [==============================] - 24s 153ms/step - loss: 0.1729 - acc: 0.9386 - val_loss: 0.7529 - val_acc: 0.8115
# Epoch 32/50
# 156/156 [==============================] - 27s 175ms/step - loss: 0.1573 - acc: 0.9446 - val_loss: 0.6766 - val_acc: 0.8354
# Epoch 33/50
# 156/156 [==============================] - 18s 117ms/step - loss: 0.1690 - acc: 0.9395 - val_loss: 0.4098 - val_acc: 0.8813
# Epoch 34/50
# 156/156 [==============================] - 21s 136ms/step - loss: 0.1708 - acc: 0.9391 - val_loss: 0.2249 - val_acc: 0.9135
# Epoch 35/50
# 156/156 [==============================] - 33s 209ms/step - loss: 0.1547 - acc: 0.9469 - val_loss: 0.5067 - val_acc: 0.8604
# Epoch 36/50
# 156/156 [==============================] - 39s 246ms/step - loss: 0.1375 - acc: 0.9506 - val_loss: 0.3939 - val_acc: 0.8958
# Epoch 37/50
# 156/156 [==============================] - 32s 205ms/step - loss: 0.1508 - acc: 0.9457 - val_loss: 0.4151 - val_acc: 0.8969
# Epoch 38/50
# 156/156 [==============================] - 35s 225ms/step - loss: 0.1594 - acc: 0.9437 - val_loss: 0.5390 - val_acc: 0.8677
# Epoch 39/50
# 156/156 [==============================] - 35s 227ms/step - loss: 0.1543 - acc: 0.9471 - val_loss: 0.8060 - val_acc: 0.8177
# Epoch 40/50
# 156/156 [==============================] - 34s 218ms/step - loss: 0.1566 - acc: 0.9441 - val_loss: 0.3766 - val_acc: 0.9000
# Epoch 41/50
# 156/156 [==============================] - 23s 149ms/step - loss: 0.1311 - acc: 0.9539 - val_loss: 0.5496 - val_acc: 0.8583
# Epoch 42/50
# 156/156 [==============================] - 33s 212ms/step - loss: 0.1374 - acc: 0.9507 - val_loss: 0.3182 - val_acc: 0.9167
# Epoch 43/50
# 156/156 [==============================] - 37s 237ms/step - loss: 0.1814 - acc: 0.9389 - val_loss: 0.3803 - val_acc: 0.8948
# Epoch 44/50
# 156/156 [==============================] - 39s 250ms/step - loss: 0.1404 - acc: 0.9505 - val_loss: 0.3506 - val_acc: 0.8875
# Epoch 45/50
# 156/156 [==============================] - 37s 236ms/step - loss: 0.1625 - acc: 0.9409 - val_loss: 0.3488 - val_acc: 0.9010
# Epoch 46/50
# 156/156 [==============================] - 50s 316ms/step - loss: 0.1132 - acc: 0.9613 - val_loss: 0.6191 - val_acc: 0.8583
# Epoch 47/50
# 156/156 [==============================] - 37s 231ms/step - loss: 0.1233 - acc: 0.9566 - val_loss: 0.6543 - val_acc: 0.8333
# Epoch 48/50
# 156/156 [==============================] - 53s 339ms/step - loss: 0.1299 - acc: 0.9550 - val_loss: 0.6487 - val_acc: 0.8625
# Epoch 49/50
# 156/156 [==============================] - 58s 367ms/step - loss: 0.1399 - acc: 0.9516 - val_loss: 0.5039 - val_acc: 0.8896
# Epoch 50/50
# 156/156 [==============================] - 69s 438ms/step - loss: 0.1085 - acc: 0.9617 - val_loss: 0.2979 - val_acc: 0.9135

# %%
import matplotlib.pyplot as plt

acc_original=history.history["acc"]
val_acc_original=history.history["val_acc"]
loss_original=history.history["loss"]
val_loss_original=history.history["val_loss"]

epochs=range(1,len(acc_original)+1)
val_epochs=range(1,len(val_acc_original)+1)


sizeplt=plt.figure()
sizeplt.set_figwidth(16)
sizeplt.set_figheight(6)

plt.plot(epochs,acc_original,'mo',label="Eğitim başarımı(original)")
plt.plot(val_epochs,val_acc_original,'m--',label="Doğrulama başarımı(original)")
plt.title("Eğitim ve Doğrulama başarımı")
plt.legend()
plt.figure()


sizeplt=plt.figure()
sizeplt.set_figwidth(16)
sizeplt.set_figheight(6)

plt.plot(epochs,loss_original,'ko',label="Eğitim kaybı(original)")
plt.plot(val_epochs,val_loss_original,'m--',label="Doğrulama kaybı(original)")
plt.title("Eğitim ve Doğrulama kaybı")
plt.legend()

plt.show()

# %%
from keras.preprocessing.image import ImageDataGenerator
# image settings

image_size=64
batch_size=32

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=40,
    width_shift_range=.2,
    height_shift_range=.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode="nearest"
    )

test_datagen = ImageDataGenerator(rescale=1./255)

# reading image

training_data = train_datagen.flow_from_directory(
    "Tomato_Dataset\\train_orj",
    target_size=(image_size,image_size),
    batch_size=batch_size,
    class_mode='categorical' 
)

# print(training_data.class_indices)

testing_data = test_datagen.flow_from_directory(
    "Tomato_Dataset\\val",
    target_size=(image_size,image_size),
    batch_size=batch_size,
    class_mode='categorical'
)

# print(testing_data.image_shape)
# print(testing_data.)
# Out:
# Found 10000 images belonging to 10 classes.
# Found 1000 images belonging to 10 classes.

# %%
from keras.preprocessing.image import ImageDataGenerator
# image settings

image_size=64
batch_size=32

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=40,
    width_shift_range=.2,
    height_shift_range=.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode="nearest"
    )

test_datagen = ImageDataGenerator(rescale=1./255)

# reading image

training_data = train_datagen.flow_from_directory(
    "Tomato_Dataset\\train_orj",
    target_size=(image_size,image_size),
    batch_size=batch_size,
    class_mode='categorical' 
)

# print(training_data.class_indices)

testing_data = test_datagen.flow_from_directory(
    "Tomato_Dataset\\val",
    target_size=(image_size,image_size),
    batch_size=batch_size,
    class_mode='categorical'
)

# print(testing_data.image_shape)
# print(testing_data.)
# Out:
# Found 10000 images belonging to 10 classes.
# Found 1000 images belonging to 10 classes.

# %%
# model

from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Dropout

model = Sequential()
model.add(Conv2D(64,(3,3),activation="relu", input_shape =(image_size,image_size,3)))
model.add(Conv2D(64,(3,3),activation="relu"))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128,(3,3),activation="relu"))
model.add(Conv2D(128,(3,3),activation="relu"))
model.add(MaxPooling2D(2,2))


model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(512,activation = "relu"))
model.add(Dense(10,activation = "softmax"))

model.compile(optimizer="adam",loss="categorical_crossentropy",metrics=["acc"])

model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_24 (Conv2D)          (None, 62, 62, 64)        1792
#
#  conv2d_25 (Conv2D)          (None, 60, 60, 64)        36928
#
#  max_pooling2d_13 (MaxPoolin  (None, 30, 30, 64)       0
#  g2D)
#
#  conv2d_26 (Conv2D)          (None, 28, 28, 128)       73856
#
#  conv2d_27 (Conv2D)          (None, 26, 26, 128)       147584
#
#  max_pooling2d_14 (MaxPoolin  (None, 13, 13, 128)      0
#  g2D)
#
#  flatten_6 (Flatten)         (None, 21632)             0
#
#  dropout_6 (Dropout)         (None, 21632)             0
#
#  dense_13 (Dense)            (None, 512)               11076096
#
#  dense_14 (Dense)            (None, 10)                5130
#
# =================================================================
# Total params: 11,341,386
# Trainable params: 11,341,386
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit_generator(
        training_data,
        steps_per_epoch=int(len(training_data)/batch_size),
        epochs=50,
        validation_data=testing_data,
        validation_steps=int(len(testing_data)/batch_size))
# Out:
# Epoch 1/50
# <ipython-input-16-f873eed78e85>:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# 9/9 [==============================] - 4s 178ms/step - loss: 2.5143 - acc: 0.0799 - val_loss: 2.2932 - val_acc: 0.1250
# Epoch 2/50
# 9/9 [==============================] - 1s 134ms/step - loss: 2.2976 - acc: 0.0868 - val_loss: 2.2921 - val_acc: 0.2188
# Epoch 3/50
# 9/9 [==============================] - 1s 141ms/step - loss: 2.2970 - acc: 0.1146 - val_loss: 2.2917 - val_acc: 0.1250
# Epoch 4/50
# 9/9 [==============================] - 1s 135ms/step - loss: 2.2799 - acc: 0.1250 - val_loss: 2.2480 - val_acc: 0.1875
# Epoch 5/50
# 9/9 [==============================] - 1s 134ms/step - loss: 2.2339 - acc: 0.1806 - val_loss: 2.2399 - val_acc: 0.1562
# Epoch 6/50
# 9/9 [==============================] - 1s 132ms/step - loss: 2.1998 - acc: 0.1944 - val_loss: 2.2764 - val_acc: 0.1562
# Epoch 7/50
# 9/9 [==============================] - 1s 133ms/step - loss: 2.1201 - acc: 0.2326 - val_loss: 2.1381 - val_acc: 0.1562
# Epoch 8/50
# 9/9 [==============================] - 1s 139ms/step - loss: 1.9566 - acc: 0.2743 - val_loss: 2.0566 - val_acc: 0.2188
# Epoch 9/50
# 2/9 [=====>........................] - ETA: 0s - loss: 2.2135 - acc: 0.1406
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\MTG\Desktop\Bitirme Tezi\tomato_leaves_disease\cnn.py in <module>
#       <a href='file:///c%3A/Users/MTG/Desktop/Bitirme%20Tezi/tomato_leaves_disease/cnn.py?line=68'>69</a> # %%
# ----> <a href='file:///c%3A/Users/MTG/Desktop/Bitirme%20Tezi/tomato_leaves_disease/cnn.py?line=69'>70</a> history = model.fit_generator(
#       <a href='file:///c%3A/Users/MTG/Desktop/Bitirme%20Tezi/tomato_leaves_disease/cnn.py?line=70'>71</a>         training_data,
#       <a href='file:///c%3A/Users/MTG/Desktop/Bitirme%20Tezi/tomato_leaves_disease/cnn.py?line=71'>72</a>         steps_per_epoch=int(len(training_data)/batch_size),
#       <a href='file:///c%3A/Users/MTG/Desktop/Bitirme%20Tezi/tomato_leaves_disease/cnn.py?line=72'>73</a>         epochs=50,
#
# c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2505             stacklevel=2,
#    2506         )
# -> 2507         return self.fit(
#    2508             generator,
#    2509             steps_per_epoch=steps_per_epoch,
#
# c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1562                         ):
#    1563                             callbacks.on_train_batch_begin(step)
# -> 1564                             tmp_logs = self.train_function(iterator)
#    1565                             if data_handler.should_sync:
#    1566                                 context.async_wait()
#
# c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2494       (graph_function,
#    2495        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496     return graph_function._call_flat(
#    2497         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2498
#
# c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1860         and executing_eagerly):
#    1861       # No tape is watching; skip to running the function.
# -> 1862       return self._build_call_outputs(self._inference_function.call(
#    1863           ctx, args, cancellation_manager=cancellation_manager))
#    1864     forward_backward = self._select_forward_and_backward_functions(
#
# c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     497       with _InterpolateFunctionError(self):
#     498         if cancellation_manager is None:
# --> 499           outputs = execute.execute(
#     500               str(self.signature.name),
#     501               num_outputs=self._num_outputs,
#
# c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
from keras.preprocessing.image import ImageDataGenerator
# image settings

image_size=64
batch_size=32

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=40,
    width_shift_range=.2,
    height_shift_range=.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode="nearest"
    )

test_datagen = ImageDataGenerator(rescale=1./255)

# reading image

training_data = train_datagen.flow_from_directory(
    "Tomato_Dataset\\train_orj",
    target_size=(image_size,image_size),
    batch_size=batch_size,
    class_mode='categorical' 
)

# print(training_data.class_indices)

testing_data = test_datagen.flow_from_directory(
    "Tomato_Dataset\\val",
    target_size=(image_size,image_size),
    batch_size=batch_size,
    class_mode='categorical'
)

int(len(training_data)/batch_size)

# print(testing_data.image_shape)
# print(testing_data.)
# Out:
# Found 10000 images belonging to 10 classes.
# Found 1000 images belonging to 10 classes.
# 9

# %%
from keras.preprocessing.image import ImageDataGenerator
# image settings

image_size=64
batch_size=32

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=40,
    width_shift_range=.2,
    height_shift_range=.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode="nearest"
    )

test_datagen = ImageDataGenerator(rescale=1./255)

# reading image

training_data = train_datagen.flow_from_directory(
    "Tomato_Dataset\\train_orj",
    target_size=(image_size,image_size),
    batch_size=batch_size,
    class_mode='categorical' 
)

# print(training_data.class_indices)

testing_data = test_datagen.flow_from_directory(
    "Tomato_Dataset\\val",
    target_size=(image_size,image_size),
    batch_size=batch_size,
    class_mode='categorical'
)

int(len(training_data))

# print(testing_data.image_shape)
# print(testing_data.)
# Out:
# Found 10000 images belonging to 10 classes.
# Found 1000 images belonging to 10 classes.
# 313

# %%
from keras.preprocessing.image import ImageDataGenerator
# image settings

image_size=64
batch_size=32

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=40,
    width_shift_range=.2,
    height_shift_range=.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode="nearest"
    )

test_datagen = ImageDataGenerator(rescale=1./255)

# reading image

training_data = train_datagen.flow_from_directory(
    "Tomato_Dataset\\train_orj",
    target_size=(image_size,image_size),
    batch_size=batch_size,
    class_mode='categorical' 
)

# print(training_data.class_indices)

testing_data = test_datagen.flow_from_directory(
    "Tomato_Dataset\\val",
    target_size=(image_size,image_size),
    batch_size=batch_size,
    class_mode='categorical'
)

int(len(train_datagen))

# print(testing_data.image_shape)
# print(testing_data.)
# Out:
# Found 10000 images belonging to 10 classes.
# Found 1000 images belonging to 10 classes.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\MTG\Desktop\Bitirme Tezi\tomato_leaves_disease\cnn.py in <module>
#      <a href='file:///c%3A/Users/MTG/Desktop/Bitirme%20Tezi/tomato_leaves_disease/cnn.py?line=38'>39</a> )
#      <a href='file:///c%3A/Users/MTG/Desktop/Bitirme%20Tezi/tomato_leaves_disease/cnn.py?line=39'>40</a>
# ---> <a href='file:///c%3A/Users/MTG/Desktop/Bitirme%20Tezi/tomato_leaves_disease/cnn.py?line=40'>41</a> int(len(train_datagen))
#      <a href='file:///c%3A/Users/MTG/Desktop/Bitirme%20Tezi/tomato_leaves_disease/cnn.py?line=41'>42</a>
#      <a href='file:///c%3A/Users/MTG/Desktop/Bitirme%20Tezi/tomato_leaves_disease/cnn.py?line=42'>43</a> # print(testing_data.image_shape)
#
# TypeError: object of type 'ImageDataGenerator' has no len()

# %%
from keras.preprocessing.image import ImageDataGenerator
# image settings

image_size=64
batch_size=32

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=40,
    width_shift_range=.2,
    height_shift_range=.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode="nearest"
    )

test_datagen = ImageDataGenerator(rescale=1./255)

# reading image

training_data = train_datagen.flow_from_directory(
    "Tomato_Dataset\\train_orj",
    target_size=(image_size,image_size),
    batch_size=batch_size,
    class_mode='categorical' 
)

# print(training_data.class_indices)

testing_data = test_datagen.flow_from_directory(
    "Tomato_Dataset\\val",
    target_size=(image_size,image_size),
    batch_size=batch_size,
    class_mode='categorical'
)

int(len(training_data.filenames))

# print(testing_data.image_shape)
# print(testing_data.)
# Out:
# Found 10000 images belonging to 10 classes.
# Found 1000 images belonging to 10 classes.
# 10000

# %%
from keras.preprocessing.image import ImageDataGenerator
# image settings

image_size=64
batch_size=32

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=40,
    width_shift_range=.2,
    height_shift_range=.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode="nearest"
    )

test_datagen = ImageDataGenerator(rescale=1./255)

# reading image

training_data = train_datagen.flow_from_directory(
    "Tomato_Dataset\\train_orj",
    target_size=(image_size,image_size),
    batch_size=batch_size,
    class_mode='categorical' 
)

# print(training_data.class_indices)

testing_data = test_datagen.flow_from_directory(
    "Tomato_Dataset\\val",
    target_size=(image_size,image_size),
    batch_size=batch_size,
    class_mode='categorical'
)

# print(testing_data.image_shape)
# print(testing_data.)
# Out:
# Found 10000 images belonging to 10 classes.
# Found 1000 images belonging to 10 classes.

# %%
# model

from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Dropout

model = Sequential()
model.add(Conv2D(64,(3,3),activation="relu", input_shape =(image_size,image_size,3)))
model.add(Conv2D(64,(3,3),activation="relu"))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128,(3,3),activation="relu"))
model.add(Conv2D(128,(3,3),activation="relu"))
model.add(MaxPooling2D(2,2))


model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(512,activation = "relu"))
model.add(Dense(10,activation = "softmax"))

model.compile(optimizer="adam",loss="categorical_crossentropy",metrics=["acc"])

model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_28 (Conv2D)          (None, 62, 62, 64)        1792
#
#  conv2d_29 (Conv2D)          (None, 60, 60, 64)        36928
#
#  max_pooling2d_15 (MaxPoolin  (None, 30, 30, 64)       0
#  g2D)
#
#  conv2d_30 (Conv2D)          (None, 28, 28, 128)       73856
#
#  conv2d_31 (Conv2D)          (None, 26, 26, 128)       147584
#
#  max_pooling2d_16 (MaxPoolin  (None, 13, 13, 128)      0
#  g2D)
#
#  flatten_7 (Flatten)         (None, 21632)             0
#
#  dropout_7 (Dropout)         (None, 21632)             0
#
#  dense_15 (Dense)            (None, 512)               11076096
#
#  dense_16 (Dense)            (None, 10)                5130
#
# =================================================================
# Total params: 11,341,386
# Trainable params: 11,341,386
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit_generator(
        training_data,
        steps_per_epoch=int(len(training_data.filenames)/batch_size),
        epochs=50,
        validation_data=testing_data,
        validation_steps=int(len(testing_data.filenames)/batch_size))
# Out:
# Epoch 1/50
# <ipython-input-23-ff31eda10610>:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# 312/312 [==============================] - 43s 135ms/step - loss: 1.9086 - acc: 0.2914 - val_loss: 1.4826 - val_acc: 0.4778
# Epoch 2/50
# 312/312 [==============================] - 41s 132ms/step - loss: 1.0788 - acc: 0.6063 - val_loss: 1.1368 - val_acc: 0.6069
# Epoch 3/50
# 312/312 [==============================] - 39s 126ms/step - loss: 0.8370 - acc: 0.6964 - val_loss: 0.7869 - val_acc: 0.7278
# Epoch 4/50
# 312/312 [==============================] - 39s 125ms/step - loss: 0.6960 - acc: 0.7571 - val_loss: 1.2187 - val_acc: 0.6230
# Epoch 5/50
# 312/312 [==============================] - 39s 125ms/step - loss: 0.5872 - acc: 0.7867 - val_loss: 0.8037 - val_acc: 0.7409
# Epoch 6/50
# 312/312 [==============================] - 39s 125ms/step - loss: 0.5436 - acc: 0.8064 - val_loss: 0.7575 - val_acc: 0.7550
# Epoch 7/50
# 312/312 [==============================] - 39s 125ms/step - loss: 0.4959 - acc: 0.8252 - val_loss: 0.9600 - val_acc: 0.7087
# Epoch 8/50
# 312/312 [==============================] - 39s 125ms/step - loss: 0.4440 - acc: 0.8422 - val_loss: 0.7333 - val_acc: 0.7722
# Epoch 9/50
# 312/312 [==============================] - 41s 132ms/step - loss: 0.4354 - acc: 0.8422 - val_loss: 1.0043 - val_acc: 0.7147
# Epoch 10/50
# 312/312 [==============================] - 46s 148ms/step - loss: 0.3758 - acc: 0.8667 - val_loss: 0.7658 - val_acc: 0.7802
# Epoch 11/50
# 312/312 [==============================] - 46s 147ms/step - loss: 0.3788 - acc: 0.8652 - val_loss: 0.6515 - val_acc: 0.7853
# Epoch 12/50
# 312/312 [==============================] - 46s 147ms/step - loss: 0.3504 - acc: 0.8755 - val_loss: 0.5749 - val_acc: 0.8256
# Epoch 13/50
# 312/312 [==============================] - 45s 144ms/step - loss: 0.3397 - acc: 0.8774 - val_loss: 0.6869 - val_acc: 0.7863
# Epoch 14/50
# 312/312 [==============================] - 39s 125ms/step - loss: 0.3107 - acc: 0.8913 - val_loss: 0.5480 - val_acc: 0.8256
# Epoch 15/50
# 312/312 [==============================] - 39s 125ms/step - loss: 0.2904 - acc: 0.8983 - val_loss: 0.6214 - val_acc: 0.8397
# Epoch 16/50
# 312/312 [==============================] - 39s 125ms/step - loss: 0.2753 - acc: 0.9049 - val_loss: 0.7665 - val_acc: 0.7954
# Epoch 17/50
# 312/312 [==============================] - 39s 125ms/step - loss: 0.2878 - acc: 0.8999 - val_loss: 0.6722 - val_acc: 0.8085
# Epoch 18/50
# 312/312 [==============================] - 39s 125ms/step - loss: 0.2679 - acc: 0.9070 - val_loss: 0.4167 - val_acc: 0.8649
# Epoch 19/50
# 312/312 [==============================] - 39s 125ms/step - loss: 0.2476 - acc: 0.9125 - val_loss: 0.6332 - val_acc: 0.8347
# Epoch 20/50
# 312/312 [==============================] - 39s 125ms/step - loss: 0.2699 - acc: 0.9043 - val_loss: 0.4067 - val_acc: 0.8921
# Epoch 21/50
# 300/312 [===========================>..] - ETA: 1s - loss: 0.2414 - acc: 0.9145
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\MTG\Desktop\Bitirme Tezi\tomato_leaves_disease\cnn.py in <module>
#       <a href='file:///c%3A/Users/MTG/Desktop/Bitirme%20Tezi/tomato_leaves_disease/cnn.py?line=68'>69</a> # %%
# ----> <a href='file:///c%3A/Users/MTG/Desktop/Bitirme%20Tezi/tomato_leaves_disease/cnn.py?line=69'>70</a> history = model.fit_generator(
#       <a href='file:///c%3A/Users/MTG/Desktop/Bitirme%20Tezi/tomato_leaves_disease/cnn.py?line=70'>71</a>         training_data,
#       <a href='file:///c%3A/Users/MTG/Desktop/Bitirme%20Tezi/tomato_leaves_disease/cnn.py?line=71'>72</a>         steps_per_epoch=int(len(training_data.filenames)/batch_size),
#       <a href='file:///c%3A/Users/MTG/Desktop/Bitirme%20Tezi/tomato_leaves_disease/cnn.py?line=72'>73</a>         epochs=50,
#
# c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2505             stacklevel=2,
#    2506         )
# -> 2507         return self.fit(
#    2508             generator,
#    2509             steps_per_epoch=steps_per_epoch,
#
# c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1562                         ):
#    1563                             callbacks.on_train_batch_begin(step)
# -> 1564                             tmp_logs = self.train_function(iterator)
#    1565                             if data_handler.should_sync:
#    1566                                 context.async_wait()
#
# c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2494       (graph_function,
#    2495        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496     return graph_function._call_flat(
#    2497         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2498
#
# c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1860         and executing_eagerly):
#    1861       # No tape is watching; skip to running the function.
# -> 1862       return self._build_call_outputs(self._inference_function.call(
#    1863           ctx, args, cancellation_manager=cancellation_manager))
#    1864     forward_backward = self._select_forward_and_backward_functions(
#
# c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     497       with _InterpolateFunctionError(self):
#     498         if cancellation_manager is None:
# --> 499           outputs = execute.execute(
#     500               str(self.signature.name),
#     501               num_outputs=self._num_outputs,
#
# c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
int(len(testing_data.filenames)/batch_size)
acc_original=history.history["acc"]
val_acc_original=history.history["val_acc"]
loss_original=history.history["loss"]
val_loss_original=history.history["val_loss"]

epochs=range(1,len(acc_original)+1)
val_epochs=range(1,len(val_acc_original)+1)


sizeplt=plt.figure()
sizeplt.set_figwidth(16)
sizeplt.set_figheight(6)

plt.plot(epochs,acc_original,'mo',label="Eğitim başarımı(original)")
plt.plot(val_epochs,val_acc_original,'m--',label="Doğrulama başarımı(original)")
plt.title("Eğitim ve Doğrulama başarımı")
plt.legend()
plt.figure()


sizeplt=plt.figure()
sizeplt.set_figwidth(16)
sizeplt.set_figheight(6)

plt.plot(epochs,loss_original,'ko',label="Eğitim kaybı(original)")
plt.plot(val_epochs,val_loss_original,'m--',label="Doğrulama kaybı(original)")
plt.title("Eğitim ve Doğrulama kaybı")
plt.legend()

plt.show()
# Out:
# Önceki hücredeki bir hata nedeniyle hücre iptal edildi.

# %%
import matplotlib.pyplot as plt
int(len(testing_data.filenames)/batch_size)
acc_original=history.history["acc"]
val_acc_original=history.history["val_acc"]
loss_original=history.history["loss"]
val_loss_original=history.history["val_loss"]

epochs=range(1,len(acc_original)+1)
val_epochs=range(1,len(val_acc_original)+1)


sizeplt=plt.figure()
sizeplt.set_figwidth(16)
sizeplt.set_figheight(6)

plt.plot(epochs,acc_original,'mo',label="Eğitim başarımı(original)")
plt.plot(val_epochs,val_acc_original,'m--',label="Doğrulama başarımı(original)")
plt.title("Eğitim ve Doğrulama başarımı")
plt.legend()
plt.figure()


sizeplt=plt.figure()
sizeplt.set_figwidth(16)
sizeplt.set_figheight(6)

plt.plot(epochs,loss_original,'ko',label="Eğitim kaybı(original)")
plt.plot(val_epochs,val_loss_original,'m--',label="Doğrulama kaybı(original)")
plt.title("Eğitim ve Doğrulama kaybı")
plt.legend()

plt.show()
# Out:
# Önceki hücredeki bir hata nedeniyle hücre iptal edildi.

# %%
import matplotlib.pyplot as plt
int(len(testing_data.filenames)/batch_size)
acc_original=history.history["acc"]
val_acc_original=history.history["val_acc"]
loss_original=history.history["loss"]
val_loss_original=history.history["val_loss"]

epochs=range(1,len(acc_original)+1)
val_epochs=range(1,len(val_acc_original)+1)


sizeplt=plt.figure()
sizeplt.set_figwidth(16)
sizeplt.set_figheight(6)

plt.plot(epochs,acc_original,'mo',label="Eğitim başarımı(original)")
plt.plot(val_epochs,val_acc_original,'m--',label="Doğrulama başarımı(original)")
plt.title("Eğitim ve Doğrulama başarımı")
plt.legend()
plt.figure()


sizeplt=plt.figure()
sizeplt.set_figwidth(16)
sizeplt.set_figheight(6)

plt.plot(epochs,loss_original,'ko',label="Eğitim kaybı(original)")
plt.plot(val_epochs,val_loss_original,'m--',label="Doğrulama kaybı(original)")
plt.title("Eğitim ve Doğrulama kaybı")
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
print(int(len(testing_data.filenames)/batch_size))
acc_original=history.history["acc"]
val_acc_original=history.history["val_acc"]
loss_original=history.history["loss"]
val_loss_original=history.history["val_loss"]

epochs=range(1,len(acc_original)+1)
val_epochs=range(1,len(val_acc_original)+1)


sizeplt=plt.figure()
sizeplt.set_figwidth(16)
sizeplt.set_figheight(6)

plt.plot(epochs,acc_original,'mo',label="Eğitim başarımı(original)")
plt.plot(val_epochs,val_acc_original,'m--',label="Doğrulama başarımı(original)")
plt.title("Eğitim ve Doğrulama başarımı")
plt.legend()
plt.figure()


sizeplt=plt.figure()
sizeplt.set_figwidth(16)
sizeplt.set_figheight(6)

plt.plot(epochs,loss_original,'ko',label="Eğitim kaybı(original)")
plt.plot(val_epochs,val_loss_original,'m--',label="Doğrulama kaybı(original)")
plt.title("Eğitim ve Doğrulama kaybı")
plt.legend()

plt.show()
# Out:
# 31

# %%
from keras.preprocessing.image import ImageDataGenerator
# image settings

image_size=64
batch_size=32

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=40,
    width_shift_range=.2,
    height_shift_range=.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode="nearest"
    )

test_datagen = ImageDataGenerator(rescale=1./255)

# reading image

training_data = train_datagen.flow_from_directory(
    "Tomato_Dataset\\train_orj",
    target_size=(image_size,image_size),
    batch_size=batch_size,
    class_mode='categorical' 
)

# print(training_data.class_indices)

testing_data = test_datagen.flow_from_directory(
    "Tomato_Dataset\\val",
    target_size=(image_size,image_size),
    batch_size=batch_size,
    class_mode='categorical'
)

# print(testing_data.image_shape)
# print(testing_data.)
# Out:
# Found 10000 images belonging to 10 classes.
# Found 1000 images belonging to 10 classes.

# %%
# model

from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Dropout

model = Sequential()
model.add(Conv2D(64,(3,3),activation="relu", input_shape =(image_size,image_size,3)))
model.add(Conv2D(64,(3,3),activation="relu"))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128,(3,3),activation="relu"))
model.add(Conv2D(128,(3,3),activation="relu"))
model.add(MaxPooling2D(2,2))


model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(512,activation = "relu"))
model.add(Dense(10,activation = "softmax"))

model.compile(optimizer="RMSprop",loss="categorical_crossentropy",metrics=["acc"])

model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_32 (Conv2D)          (None, 62, 62, 64)        1792
#
#  conv2d_33 (Conv2D)          (None, 60, 60, 64)        36928
#
#  max_pooling2d_17 (MaxPoolin  (None, 30, 30, 64)       0
#  g2D)
#
#  conv2d_34 (Conv2D)          (None, 28, 28, 128)       73856
#
#  conv2d_35 (Conv2D)          (None, 26, 26, 128)       147584
#
#  max_pooling2d_18 (MaxPoolin  (None, 13, 13, 128)      0
#  g2D)
#
#  flatten_8 (Flatten)         (None, 21632)             0
#
#  dropout_8 (Dropout)         (None, 21632)             0
#
#  dense_17 (Dense)            (None, 512)               11076096
#
#  dense_18 (Dense)            (None, 10)                5130
#
# =================================================================
# Total params: 11,341,386
# Trainable params: 11,341,386
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit_generator(
        training_data,
        steps_per_epoch=int(len(training_data.filenames)/batch_size),
        epochs=12,
        validation_data=testing_data,
        validation_steps=int(len(testing_data.filenames)/batch_size))
# Out:
# Epoch 1/12
# <ipython-input-28-ac7204a7e9e0>:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# 312/312 [==============================] - 53s 166ms/step - loss: 2.0460 - acc: 0.2840 - val_loss: 2.0119 - val_acc: 0.4042
# Epoch 2/12
# 312/312 [==============================] - 55s 176ms/step - loss: 1.3906 - acc: 0.5144 - val_loss: 1.1776 - val_acc: 0.5867
# Epoch 3/12
# 312/312 [==============================] - 47s 151ms/step - loss: 1.0609 - acc: 0.6405 - val_loss: 1.2634 - val_acc: 0.5927
# Epoch 4/12
# 312/312 [==============================] - 48s 153ms/step - loss: 0.9057 - acc: 0.6882 - val_loss: 0.7069 - val_acc: 0.7409
# Epoch 5/12
# 312/312 [==============================] - 48s 152ms/step - loss: 0.8078 - acc: 0.7341 - val_loss: 0.7297 - val_acc: 0.7651
# Epoch 6/12
# 312/312 [==============================] - 49s 157ms/step - loss: 0.7047 - acc: 0.7638 - val_loss: 1.1254 - val_acc: 0.6683
# Epoch 7/12
# 312/312 [==============================] - 48s 153ms/step - loss: 0.6550 - acc: 0.7831 - val_loss: 1.2085 - val_acc: 0.6633
# Epoch 8/12
# 312/312 [==============================] - 47s 152ms/step - loss: 0.6107 - acc: 0.7961 - val_loss: 0.4798 - val_acc: 0.8508
# Epoch 9/12
# 312/312 [==============================] - 49s 158ms/step - loss: 0.5605 - acc: 0.8186 - val_loss: 0.5565 - val_acc: 0.8337
# Epoch 10/12
# 312/312 [==============================] - 48s 153ms/step - loss: 0.5276 - acc: 0.8272 - val_loss: 0.6619 - val_acc: 0.7923
# Epoch 11/12
# 312/312 [==============================] - 48s 153ms/step - loss: 0.5356 - acc: 0.8283 - val_loss: 1.9283 - val_acc: 0.6079
# Epoch 12/12
# 248/312 [======================>.......] - ETA: 9s - loss: 0.4808 - acc: 0.8485
# ---------------------------------------------------------------------------
# UnknownError                              Traceback (most recent call last)
# c:\Users\MTG\Desktop\Bitirme Tezi\tomato_leaves_disease\cnn.py in <module>
#       <a href='file:///c%3A/Users/MTG/Desktop/Bitirme%20Tezi/tomato_leaves_disease/cnn.py?line=68'>69</a> # %%
# ----> <a href='file:///c%3A/Users/MTG/Desktop/Bitirme%20Tezi/tomato_leaves_disease/cnn.py?line=69'>70</a> history = model.fit_generator(
#       <a href='file:///c%3A/Users/MTG/Desktop/Bitirme%20Tezi/tomato_leaves_disease/cnn.py?line=70'>71</a>         training_data,
#       <a href='file:///c%3A/Users/MTG/Desktop/Bitirme%20Tezi/tomato_leaves_disease/cnn.py?line=71'>72</a>         steps_per_epoch=int(len(training_data.filenames)/batch_size),
#       <a href='file:///c%3A/Users/MTG/Desktop/Bitirme%20Tezi/tomato_leaves_disease/cnn.py?line=72'>73</a>         epochs=12,
#
# c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2505             stacklevel=2,
#    2506         )
# -> 2507         return self.fit(
#    2508             generator,
#    2509             steps_per_epoch=steps_per_epoch,
#
# c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# UnknownError: Graph execution error:
#
# 2 root error(s) found.
#   (0) UNKNOWN:  FileNotFoundError: [Errno 2] No such file or directory: 'Tomato_Dataset\\train_orj\\Tomato___Bacterial_spot\\8491569f-a7d8-453c-86ae-c2accdc964c9___GCREC_Bact.Sp 5943.JPG'
# Traceback (most recent call last):
#
#   File "c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\ops\script_ops.py", line 271, in __call__
#     ret = func(*args)
#
#   File "c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\autograph\impl\api.py", line 642, in wrapper
#     return func(*args, **kwargs)
#
#   File "c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py", line 1035, in generator_py_func
#     values = next(generator_state.get_iterator(iterator_id))
#
#   File "c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\data_adapter.py", line 903, in wrapped_generator
#     for data in generator_fn():
#
#   File "c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\data_adapter.py", line 1050, in generator_fn
#     yield x[i]
#
#   File "c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\preprocessing\image.py", line 116, in __getitem__
#     return self._get_batches_of_transformed_samples(index_array)
#
#   File "c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\preprocessing\image.py", line 370, in _get_batches_of_transformed_samples
#     img = image_utils.load_img(
#
#   File "c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\image_utils.py", line 422, in load_img
#     with open(path, "rb") as f:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Tomato_Dataset\\train_orj\\Tomato___Bacterial_spot\\8491569f-a7d8-453c-86ae-c2accdc964c9___GCREC_Bact.Sp 5943.JPG'
#
#
# 	 [[{{node PyFunc}}]]
# 	 [[IteratorGetNext]]
# 	 [[IteratorGetNext/_4]]
#   (1) UNKNOWN:  FileNotFoundError: [Errno 2] No such file or directory: 'Tomato_Dataset\\train_orj\\Tomato___Bacterial_spot\\8491569f-a7d8-453c-86ae-c2accdc964c9___GCREC_Bact.Sp 5943.JPG'
# Traceback (most recent call last):
#
#   File "c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\ops\script_ops.py", line 271, in __call__
#     ret = func(*args)
#
#   File "c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\autograph\impl\api.py", line 642, in wrapper
#     return func(*args, **kwargs)
#
#   File "c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py", line 1035, in generator_py_func
#     values = next(generator_state.get_iterator(iterator_id))
#
#   File "c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\data_adapter.py", line 903, in wrapped_generator
#     for data in generator_fn():
#
#   File "c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\data_adapter.py", line 1050, in generator_fn
#     yield x[i]
#
#   File "c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\preprocessing\image.py", line 116, in __getitem__
#     return self._get_batches_of_transformed_samples(index_array)
#
#   File "c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\preprocessing\image.py", line 370, in _get_batches_of_transformed_samples
#     img = image_utils.load_img(
#
#   File "c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\image_utils.py", line 422, in load_img
#     with open(path, "rb") as f:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Tomato_Dataset\\train_orj\\Tomato___Bacterial_spot\\8491569f-a7d8-453c-86ae-c2accdc964c9___GCREC_Bact.Sp 5943.JPG'
#
#
# 	 [[{{node PyFunc}}]]
# 	 [[IteratorGetNext]]
# 0 successful operations.
# 0 derived errors ignored. [Op:__inference_train_function_106344]

# %%
import matplotlib.pyplot as plt
acc_original=history.history["acc"]
val_acc_original=history.history["val_acc"]
loss_original=history.history["loss"]
val_loss_original=history.history["val_loss"]

epochs=range(1,len(acc_original)+1)
val_epochs=range(1,len(val_acc_original)+1)


sizeplt=plt.figure()
sizeplt.set_figwidth(16)
sizeplt.set_figheight(6)

plt.plot(epochs,acc_original,'mo',label="Eğitim başarımı(original)")
plt.plot(val_epochs,val_acc_original,'m--',label="Doğrulama başarımı(original)")
plt.title("Eğitim ve Doğrulama başarımı")
plt.legend()
plt.figure()


sizeplt=plt.figure()
sizeplt.set_figwidth(16)
sizeplt.set_figheight(6)

plt.plot(epochs,loss_original,'ko',label="Eğitim kaybı(original)")
plt.plot(val_epochs,val_loss_original,'m--',label="Doğrulama kaybı(original)")
plt.title("Eğitim ve Doğrulama kaybı")
plt.legend()

plt.show()
# Out:
# Önceki hücredeki bir hata nedeniyle hücre iptal edildi.

# %%
from keras.preprocessing.image import ImageDataGenerator
# image settings

image_size=32
batch_size=32

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=40,
    width_shift_range=.2,
    height_shift_range=.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode="nearest"
    )

test_datagen = ImageDataGenerator(rescale=1./255)

# reading image

training_data = train_datagen.flow_from_directory(
    "Tomato_Dataset\\train_orj",
    target_size=(image_size,image_size),
    batch_size=batch_size,
    class_mode='categorical' 
)

# print(training_data.class_indices)

testing_data = test_datagen.flow_from_directory(
    "Tomato_Dataset\\val",
    target_size=(image_size,image_size),
    batch_size=batch_size,
    class_mode='categorical'
)

# print(testing_data.image_shape)
# print(testing_data.)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\MTG\Desktop\Bitirme Tezi\tomato_leaves_disease\cnn.py in <module>
#      <a href='file:///c%3A/Users/MTG/Desktop/Bitirme%20Tezi/tomato_leaves_disease/cnn.py?line=22'>23</a> # reading image
#      <a href='file:///c%3A/Users/MTG/Desktop/Bitirme%20Tezi/tomato_leaves_disease/cnn.py?line=23'>24</a>
# ---> <a href='file:///c%3A/Users/MTG/Desktop/Bitirme%20Tezi/tomato_leaves_disease/cnn.py?line=24'>25</a> training_data = train_datagen.flow_from_directory(
#      <a href='file:///c%3A/Users/MTG/Desktop/Bitirme%20Tezi/tomato_leaves_disease/cnn.py?line=25'>26</a>     "Tomato_Dataset\\train_orj",
#      <a href='file:///c%3A/Users/MTG/Desktop/Bitirme%20Tezi/tomato_leaves_disease/cnn.py?line=26'>27</a>     target_size=(image_size,image_size),
#
# c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\preprocessing\image.py in flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio)
#    1648                 and `y` is a numpy array of corresponding labels.
#    1649         """
# -> 1650         return DirectoryIterator(
#    1651             directory,
#    1652             self,
#
# c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\preprocessing\image.py in __init__(self, directory, image_data_generator, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, data_format, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio, dtype)
#     561         if not classes:
#     562             classes = []
# --> 563             for subdir in sorted(os.listdir(directory)):
#     564                 if os.path.isdir(os.path.join(directory, subdir)):
#     565                     classes.append(subdir)
#
# FileNotFoundError: [WinError 3] Sistem belirtilen yolu bulamıyor: 'Tomato_Dataset\\train_orj'

# %%
from keras.preprocessing.image import ImageDataGenerator
# image settings

image_size=32
batch_size=32

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=40,
    width_shift_range=.2,
    height_shift_range=.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode="nearest"
    )

test_datagen = ImageDataGenerator(rescale=1./255)

# reading image

training_data = train_datagen.flow_from_directory(
    "Tomato_Dataset\\train_orj",
    target_size=(image_size,image_size),
    batch_size=batch_size,
    class_mode='categorical' 
)

# print(training_data.class_indices)

testing_data = test_datagen.flow_from_directory(
    "Tomato_Dataset\\val",
    target_size=(image_size,image_size),
    batch_size=batch_size,
    class_mode='categorical'
)

# print(testing_data.image_shape)
# print(testing_data.)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\MTG\Desktop\Bitirme Tezi\tomato_leaves_disease\cnn.py in <module>
#      <a href='file:///c%3A/Users/MTG/Desktop/Bitirme%20Tezi/tomato_leaves_disease/cnn.py?line=22'>23</a> # reading image
#      <a href='file:///c%3A/Users/MTG/Desktop/Bitirme%20Tezi/tomato_leaves_disease/cnn.py?line=23'>24</a>
# ---> <a href='file:///c%3A/Users/MTG/Desktop/Bitirme%20Tezi/tomato_leaves_disease/cnn.py?line=24'>25</a> training_data = train_datagen.flow_from_directory(
#      <a href='file:///c%3A/Users/MTG/Desktop/Bitirme%20Tezi/tomato_leaves_disease/cnn.py?line=25'>26</a>     "Tomato_Dataset\\train_orj",
#      <a href='file:///c%3A/Users/MTG/Desktop/Bitirme%20Tezi/tomato_leaves_disease/cnn.py?line=26'>27</a>     target_size=(image_size,image_size),
#
# c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\preprocessing\image.py in flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio)
#    1648                 and `y` is a numpy array of corresponding labels.
#    1649         """
# -> 1650         return DirectoryIterator(
#    1651             directory,
#    1652             self,
#
# c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\preprocessing\image.py in __init__(self, directory, image_data_generator, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, data_format, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio, dtype)
#     561         if not classes:
#     562             classes = []
# --> 563             for subdir in sorted(os.listdir(directory)):
#     564                 if os.path.isdir(os.path.join(directory, subdir)):
#     565                     classes.append(subdir)
#
# FileNotFoundError: [WinError 3] Sistem belirtilen yolu bulamıyor: 'Tomato_Dataset\\train_orj'

# %%
from keras.preprocessing.image import ImageDataGenerator
# image settings

image_size=32
batch_size=32

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=40,
    width_shift_range=.2,
    height_shift_range=.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode="nearest"
    )

test_datagen = ImageDataGenerator(rescale=1./255)

# reading image

training_data = train_datagen.flow_from_directory(
    "Tomato_Dataset\\train_orj",
    target_size=(image_size,image_size),
    batch_size=batch_size,
    class_mode='categorical' 
)

# print(training_data.class_indices)

testing_data = test_datagen.flow_from_directory(
    "Tomato_Dataset\\val",
    target_size=(image_size,image_size),
    batch_size=batch_size,
    class_mode='categorical'
)

# print(testing_data.image_shape)
# print(testing_data.)
# Out:
# Found 10000 images belonging to 10 classes.
# Found 1000 images belonging to 10 classes.

# %%
# model

from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Dropout

model = Sequential()
model.add(Conv2D(64,(3,3),activation="relu", input_shape =(image_size,image_size,3)))
model.add(Conv2D(64,(3,3),activation="relu"))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128,(3,3),activation="relu"))
model.add(Conv2D(128,(3,3),activation="relu"))
model.add(MaxPooling2D(2,2))


model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(512,activation = "relu"))
model.add(Dense(10,activation = "softmax"))

model.compile(optimizer="RMSprop",loss="categorical_crossentropy",metrics=["acc"])

model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_36 (Conv2D)          (None, 30, 30, 64)        1792
#
#  conv2d_37 (Conv2D)          (None, 28, 28, 64)        36928
#
#  max_pooling2d_19 (MaxPoolin  (None, 14, 14, 64)       0
#  g2D)
#
#  conv2d_38 (Conv2D)          (None, 12, 12, 128)       73856
#
#  conv2d_39 (Conv2D)          (None, 10, 10, 128)       147584
#
#  max_pooling2d_20 (MaxPoolin  (None, 5, 5, 128)        0
#  g2D)
#
#  flatten_9 (Flatten)         (None, 3200)              0
#
#  dropout_9 (Dropout)         (None, 3200)              0
#
#  dense_19 (Dense)            (None, 512)               1638912
#
#  dense_20 (Dense)            (None, 10)                5130
#
# =================================================================
# Total params: 1,904,202
# Trainable params: 1,904,202
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit_generator(
        training_data,
        steps_per_epoch=312,
        epochs=12,
        validation_data=testing_data,
        validation_steps=30)
# Out:
# <ipython-input-33-38860f45d7f9>:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# Epoch 1/12
# 312/312 [==============================] - 74s 233ms/step - loss: 2.1373 - acc: 0.2147 - val_loss: 1.9847 - val_acc: 0.3260
# Epoch 2/12
# 312/312 [==============================] - 14s 45ms/step - loss: 1.6186 - acc: 0.4148 - val_loss: 2.0675 - val_acc: 0.3615
# Epoch 3/12
# 312/312 [==============================] - 14s 44ms/step - loss: 1.2833 - acc: 0.5534 - val_loss: 1.4697 - val_acc: 0.5042
# Epoch 4/12
# 312/312 [==============================] - 15s 48ms/step - loss: 1.0802 - acc: 0.6214 - val_loss: 1.4715 - val_acc: 0.4979
# Epoch 5/12
# 312/312 [==============================] - 16s 50ms/step - loss: 0.9197 - acc: 0.6782 - val_loss: 1.1541 - val_acc: 0.6344
# Epoch 6/12
# 312/312 [==============================] - 22s 70ms/step - loss: 0.8353 - acc: 0.7111 - val_loss: 1.0337 - val_acc: 0.6802
# Epoch 7/12
# 312/312 [==============================] - 30s 95ms/step - loss: 0.7682 - acc: 0.7419 - val_loss: 1.5360 - val_acc: 0.5562
# Epoch 8/12
# 312/312 [==============================] - 21s 68ms/step - loss: 0.7144 - acc: 0.7568 - val_loss: 0.9914 - val_acc: 0.6875
# Epoch 9/12
# 312/312 [==============================] - 16s 51ms/step - loss: 0.6782 - acc: 0.7744 - val_loss: 0.6745 - val_acc: 0.7979
# Epoch 10/12
# 312/312 [==============================] - 14s 46ms/step - loss: 0.6338 - acc: 0.7851 - val_loss: 0.5951 - val_acc: 0.8219
# Epoch 11/12
# 312/312 [==============================] - 14s 46ms/step - loss: 0.6372 - acc: 0.7929 - val_loss: 0.9735 - val_acc: 0.7167
# Epoch 12/12
# 312/312 [==============================] - 23s 75ms/step - loss: 0.5997 - acc: 0.8022 - val_loss: 1.6237 - val_acc: 0.6115

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.10.0'

# %%
# model

from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Dropout

model = Sequential()
model.add(Conv2D(64,(3,3),activation="relu", input_shape =(image_size,image_size,3)))
model.add(Conv2D(64,(3,3),activation="relu"))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128,(3,3),activation="relu"))
model.add(Conv2D(128,(3,3),activation="relu"))
model.add(MaxPooling2D(2,2))


model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(512,activation = "relu"))
model.add(Dense(10,activation = "softmax"))

model.compile(optimizer="RMSprop",loss="categorical_crossentropy",metrics=["acc"])

model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_40 (Conv2D)          (None, 30, 30, 64)        1792
#
#  conv2d_41 (Conv2D)          (None, 28, 28, 64)        36928
#
#  max_pooling2d_21 (MaxPoolin  (None, 14, 14, 64)       0
#  g2D)
#
#  conv2d_42 (Conv2D)          (None, 12, 12, 128)       73856
#
#  conv2d_43 (Conv2D)          (None, 10, 10, 128)       147584
#
#  max_pooling2d_22 (MaxPoolin  (None, 5, 5, 128)        0
#  g2D)
#
#  flatten_10 (Flatten)        (None, 3200)              0
#
#  dropout_10 (Dropout)        (None, 3200)              0
#
#  dense_21 (Dense)            (None, 512)               1638912
#
#  dense_22 (Dense)            (None, 10)                5130
#
# =================================================================
# Total params: 1,904,202
# Trainable params: 1,904,202
# Non-trainable params: 0
# _________________________________________________________________

# %%
import matplotlib.pyplot as plt
acc_original=history.history["acc"]
val_acc_original=history.history["val_acc"]
loss_original=history.history["loss"]
val_loss_original=history.history["val_loss"]

epochs=range(1,len(acc_original)+1)
val_epochs=range(1,len(val_acc_original)+1)


sizeplt=plt.figure()
sizeplt.set_figwidth(16)
sizeplt.set_figheight(6)

plt.plot(epochs,acc_original,'mo',label="Eğitim başarımı(original)")
plt.plot(val_epochs,val_acc_original,'m--',label="Doğrulama başarımı(original)")
plt.title("Eğitim ve Doğrulama başarımı")
plt.legend()
plt.figure()


sizeplt=plt.figure()
sizeplt.set_figwidth(16)
sizeplt.set_figheight(6)

plt.plot(epochs,loss_original,'ko',label="Eğitim kaybı(original)")
plt.plot(val_epochs,val_loss_original,'m--',label="Doğrulama kaybı(original)")
plt.title("Eğitim ve Doğrulama kaybı")
plt.legend()

plt.show()

# %%
# model

from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Dropout

model = Sequential()
model.add(Conv2D(64,(3,3),activation="relu", input_shape =(image_size,image_size,3)))
model.add(Conv2D(64,(3,3),activation="relu"))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128,(3,3),activation="relu"))
model.add(Conv2D(128,(3,3),activation="relu"))
model.add(MaxPooling2D(2,2))


model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(512,activation = "relu"))
model.add(Dense(10,activation = "softmax"))

model.compile(optimizer="RMSprop",loss="categorical_crossentropy",metrics=["acc"])

model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_44 (Conv2D)          (None, 30, 30, 64)        1792
#
#  conv2d_45 (Conv2D)          (None, 28, 28, 64)        36928
#
#  max_pooling2d_23 (MaxPoolin  (None, 14, 14, 64)       0
#  g2D)
#
#  conv2d_46 (Conv2D)          (None, 12, 12, 128)       73856
#
#  conv2d_47 (Conv2D)          (None, 10, 10, 128)       147584
#
#  max_pooling2d_24 (MaxPoolin  (None, 5, 5, 128)        0
#  g2D)
#
#  flatten_11 (Flatten)        (None, 3200)              0
#
#  dropout_11 (Dropout)        (None, 3200)              0
#
#  dense_23 (Dense)            (None, 512)               1638912
#
#  dense_24 (Dense)            (None, 10)                5130
#
# =================================================================
# Total params: 1,904,202
# Trainable params: 1,904,202
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit_generator(
        training_data,
        steps_per_epoch=312,
        epochs=12,
        validation_data=testing_data,
        validation_steps=30)
# Out:
# Epoch 1/12
# <ipython-input-38-38860f45d7f9>:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# 201/312 [==================>...........] - ETA: 5s - loss: 2.1301 - acc: 0.2167
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\MTG\Desktop\Bitirme Tezi\tomato_leaves_disease\cnn.py in <module>
#       <a href='file:///c%3A/Users/MTG/Desktop/Bitirme%20Tezi/tomato_leaves_disease/cnn.py?line=68'>69</a> # %%
# ----> <a href='file:///c%3A/Users/MTG/Desktop/Bitirme%20Tezi/tomato_leaves_disease/cnn.py?line=69'>70</a> history = model.fit_generator(
#       <a href='file:///c%3A/Users/MTG/Desktop/Bitirme%20Tezi/tomato_leaves_disease/cnn.py?line=70'>71</a>         training_data,
#       <a href='file:///c%3A/Users/MTG/Desktop/Bitirme%20Tezi/tomato_leaves_disease/cnn.py?line=71'>72</a>         steps_per_epoch=312,
#       <a href='file:///c%3A/Users/MTG/Desktop/Bitirme%20Tezi/tomato_leaves_disease/cnn.py?line=72'>73</a>         epochs=12,
#
# c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2505             stacklevel=2,
#    2506         )
# -> 2507         return self.fit(
#    2508             generator,
#    2509             steps_per_epoch=steps_per_epoch,
#
# c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1562                         ):
#    1563                             callbacks.on_train_batch_begin(step)
# -> 1564                             tmp_logs = self.train_function(iterator)
#    1565                             if data_handler.should_sync:
#    1566                                 context.async_wait()
#
# c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2494       (graph_function,
#    2495        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496     return graph_function._call_flat(
#    2497         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2498
#
# c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1860         and executing_eagerly):
#    1861       # No tape is watching; skip to running the function.
# -> 1862       return self._build_call_outputs(self._inference_function.call(
#    1863           ctx, args, cancellation_manager=cancellation_manager))
#    1864     forward_backward = self._select_forward_and_backward_functions(
#
# c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     497       with _InterpolateFunctionError(self):
#     498         if cancellation_manager is None:
# --> 499           outputs = execute.execute(
#     500               str(self.signature.name),
#     501               num_outputs=self._num_outputs,
#
# c:\Users\MTG\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# model

from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Dropout

model = Sequential()
model.add(Conv2D(64,(3,3),activation="relu", input_shape =(image_size,image_size,3)))
model.add(Conv2D(64,(3,3),activation="relu"))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128,(3,3),activation="relu"))
model.add(Conv2D(128,(3,3),activation="relu"))
model.add(MaxPooling2D(2,2))


model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(512,activation = "relu"))
model.add(Dense(10,activation = "softmax"))

model.compile(optimizer="Adadelta",loss="categorical_crossentropy",metrics=["acc"])

model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_48 (Conv2D)          (None, 30, 30, 64)        1792
#
#  conv2d_49 (Conv2D)          (None, 28, 28, 64)        36928
#
#  max_pooling2d_25 (MaxPoolin  (None, 14, 14, 64)       0
#  g2D)
#
#  conv2d_50 (Conv2D)          (None, 12, 12, 128)       73856
#
#  conv2d_51 (Conv2D)          (None, 10, 10, 128)       147584
#
#  max_pooling2d_26 (MaxPoolin  (None, 5, 5, 128)        0
#  g2D)
#
#  flatten_12 (Flatten)        (None, 3200)              0
#
#  dropout_12 (Dropout)        (None, 3200)              0
#
#  dense_25 (Dense)            (None, 512)               1638912
#
#  dense_26 (Dense)            (None, 10)                5130
#
# =================================================================
# Total params: 1,904,202
# Trainable params: 1,904,202
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit_generator(
        training_data,
        steps_per_epoch=312,
        epochs=12,
        validation_data=testing_data,
        validation_steps=30)
# Out:
# Epoch 1/12
# <ipython-input-40-38860f45d7f9>:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# 312/312 [==============================] - 18s 56ms/step - loss: 2.3074 - acc: 0.0950 - val_loss: 2.3068 - val_acc: 0.1208
# Epoch 2/12
# 312/312 [==============================] - 15s 49ms/step - loss: 2.3064 - acc: 0.0988 - val_loss: 2.3055 - val_acc: 0.1208
# Epoch 3/12
# 312/312 [==============================] - 17s 53ms/step - loss: 2.3048 - acc: 0.1024 - val_loss: 2.3043 - val_acc: 0.1292
# Epoch 4/12
# 312/312 [==============================] - 17s 56ms/step - loss: 2.3041 - acc: 0.1033 - val_loss: 2.3026 - val_acc: 0.1490
# Epoch 5/12
# 312/312 [==============================] - 17s 53ms/step - loss: 2.3031 - acc: 0.1020 - val_loss: 2.3016 - val_acc: 0.1417
# Epoch 6/12
# 312/312 [==============================] - 15s 49ms/step - loss: 2.3025 - acc: 0.1060 - val_loss: 2.3006 - val_acc: 0.1312
# Epoch 7/12
# 312/312 [==============================] - 16s 51ms/step - loss: 2.3013 - acc: 0.1038 - val_loss: 2.2999 - val_acc: 0.1052
# Epoch 8/12
# 312/312 [==============================] - 15s 48ms/step - loss: 2.3012 - acc: 0.1070 - val_loss: 2.2985 - val_acc: 0.0958
# Epoch 9/12
# 312/312 [==============================] - 16s 50ms/step - loss: 2.3006 - acc: 0.1044 - val_loss: 2.2979 - val_acc: 0.0948
# Epoch 10/12
# 312/312 [==============================] - 16s 51ms/step - loss: 2.2996 - acc: 0.1108 - val_loss: 2.2975 - val_acc: 0.0979
# Epoch 11/12
# 312/312 [==============================] - 16s 52ms/step - loss: 2.2998 - acc: 0.1092 - val_loss: 2.2964 - val_acc: 0.1000
# Epoch 12/12
# 312/312 [==============================] - 15s 47ms/step - loss: 2.2995 - acc: 0.1029 - val_loss: 2.2956 - val_acc: 0.1000

# %%
print("RMSprop")
print("Adadelta")
# Out:
# RMSprop
# Adadelta

# %%
import matplotlib.pyplot as plt
acc_original=history.history["acc"]
val_acc_original=history.history["val_acc"]
loss_original=history.history["loss"]
val_loss_original=history.history["val_loss"]

epochs=range(1,len(acc_original)+1)
val_epochs=range(1,len(val_acc_original)+1)


sizeplt=plt.figure()
sizeplt.set_figwidth(16)
sizeplt.set_figheight(6)

plt.plot(epochs,acc_original,'mo',label="Eğitim başarımı(original)")
plt.plot(val_epochs,val_acc_original,'m--',label="Doğrulama başarımı(original)")
plt.title("Eğitim ve Doğrulama başarımı")
plt.legend()
plt.figure()


sizeplt=plt.figure()
sizeplt.set_figwidth(16)
sizeplt.set_figheight(6)

plt.plot(epochs,loss_original,'ko',label="Eğitim kaybı(original)")
plt.plot(val_epochs,val_loss_original,'m--',label="Doğrulama kaybı(original)")
plt.title("Eğitim ve Doğrulama kaybı")
plt.legend()

plt.show()

# %%
# model

from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Dropout

model = Sequential()
model.add(Conv2D(64,(3,3),activation="relu", input_shape =(image_size,image_size,3)))
model.add(Conv2D(64,(3,3),activation="relu"))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128,(3,3),activation="relu"))
model.add(Conv2D(128,(3,3),activation="relu"))
model.add(MaxPooling2D(2,2))


model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(512,activation = "relu"))
model.add(Dense(10,activation = "softmax"))

model.compile(optimizer="SGD",loss="categorical_crossentropy",metrics=["acc"])

model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_52 (Conv2D)          (None, 30, 30, 64)        1792
#
#  conv2d_53 (Conv2D)          (None, 28, 28, 64)        36928
#
#  max_pooling2d_27 (MaxPoolin  (None, 14, 14, 64)       0
#  g2D)
#
#  conv2d_54 (Conv2D)          (None, 12, 12, 128)       73856
#
#  conv2d_55 (Conv2D)          (None, 10, 10, 128)       147584
#
#  max_pooling2d_28 (MaxPoolin  (None, 5, 5, 128)        0
#  g2D)
#
#  flatten_13 (Flatten)        (None, 3200)              0
#
#  dropout_13 (Dropout)        (None, 3200)              0
#
#  dense_27 (Dense)            (None, 512)               1638912
#
#  dense_28 (Dense)            (None, 10)                5130
#
# =================================================================
# Total params: 1,904,202
# Trainable params: 1,904,202
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit_generator(
        training_data,
        steps_per_epoch=312,
        epochs=12,
        validation_data=testing_data,
        validation_steps=30)
# Out:
# Epoch 1/12
# <ipython-input-44-38860f45d7f9>:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# 312/312 [==============================] - 15s 45ms/step - loss: 2.3013 - acc: 0.1068 - val_loss: 2.2919 - val_acc: 0.1021
# Epoch 2/12
# 312/312 [==============================] - 15s 47ms/step - loss: 2.2838 - acc: 0.1436 - val_loss: 2.2477 - val_acc: 0.1833
# Epoch 3/12
# 312/312 [==============================] - 15s 47ms/step - loss: 2.1917 - acc: 0.1908 - val_loss: 2.0692 - val_acc: 0.2656
# Epoch 4/12
# 312/312 [==============================] - 13s 41ms/step - loss: 2.0771 - acc: 0.2457 - val_loss: 1.8976 - val_acc: 0.3396
# Epoch 5/12
# 312/312 [==============================] - 13s 42ms/step - loss: 1.9455 - acc: 0.3038 - val_loss: 1.6886 - val_acc: 0.4167
# Epoch 6/12
# 312/312 [==============================] - 13s 42ms/step - loss: 1.8305 - acc: 0.3496 - val_loss: 1.5314 - val_acc: 0.4677
# Epoch 7/12
# 312/312 [==============================] - 14s 43ms/step - loss: 1.7179 - acc: 0.3846 - val_loss: 1.4730 - val_acc: 0.4490
# Epoch 8/12
# 312/312 [==============================] - 13s 43ms/step - loss: 1.6003 - acc: 0.4291 - val_loss: 1.7392 - val_acc: 0.4021
# Epoch 9/12
# 312/312 [==============================] - 23s 75ms/step - loss: 1.5639 - acc: 0.4471 - val_loss: 1.3645 - val_acc: 0.5562
# Epoch 10/12
# 312/312 [==============================] - 13s 43ms/step - loss: 1.4876 - acc: 0.4687 - val_loss: 1.2896 - val_acc: 0.5469
# Epoch 11/12
# 312/312 [==============================] - 16s 52ms/step - loss: 1.3860 - acc: 0.5074 - val_loss: 1.1862 - val_acc: 0.5729
# Epoch 12/12
# 312/312 [==============================] - 13s 42ms/step - loss: 1.3510 - acc: 0.5267 - val_loss: 1.2282 - val_acc: 0.5823

# %%
import matplotlib.pyplot as plt
acc_original=history.history["acc"]
val_acc_original=history.history["val_acc"]
loss_original=history.history["loss"]
val_loss_original=history.history["val_loss"]

epochs=range(1,len(acc_original)+1)
val_epochs=range(1,len(val_acc_original)+1)


sizeplt=plt.figure()
sizeplt.set_figwidth(16)
sizeplt.set_figheight(6)

plt.plot(epochs,acc_original,'mo',label="Eğitim başarımı(original)")
plt.plot(val_epochs,val_acc_original,'m--',label="Doğrulama başarımı(original)")
plt.title("Eğitim ve Doğrulama başarımı")
plt.legend()
plt.figure()


sizeplt=plt.figure()
sizeplt.set_figwidth(16)
sizeplt.set_figheight(6)

plt.plot(epochs,loss_original,'ko',label="Eğitim kaybı(original)")
plt.plot(val_epochs,val_loss_original,'m--',label="Doğrulama kaybı(original)")
plt.title("Eğitim ve Doğrulama kaybı")
plt.legend()

plt.show()

# %%
print("SGD")
# Out:
# SGD

# %%
# model

from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Dropout

model = Sequential()
model.add(Conv2D(64,(3,3),activation="relu", input_shape =(image_size,image_size,3)))
model.add(Conv2D(64,(3,3),activation="relu"))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128,(3,3),activation="relu"))
model.add(Conv2D(128,(3,3),activation="relu"))
model.add(MaxPooling2D(2,2))


model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(512,activation = "relu"))
model.add(Dense(10,activation = "softmax"))

model.compile(optimizer="Adam",loss="categorical_crossentropy",metrics=["acc"])

model.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_56 (Conv2D)          (None, 30, 30, 64)        1792
#
#  conv2d_57 (Conv2D)          (None, 28, 28, 64)        36928
#
#  max_pooling2d_29 (MaxPoolin  (None, 14, 14, 64)       0
#  g2D)
#
#  conv2d_58 (Conv2D)          (None, 12, 12, 128)       73856
#
#  conv2d_59 (Conv2D)          (None, 10, 10, 128)       147584
#
#  max_pooling2d_30 (MaxPoolin  (None, 5, 5, 128)        0
#  g2D)
#
#  flatten_14 (Flatten)        (None, 3200)              0
#
#  dropout_14 (Dropout)        (None, 3200)              0
#
#  dense_29 (Dense)            (None, 512)               1638912
#
#  dense_30 (Dense)            (None, 10)                5130
#
# =================================================================
# Total params: 1,904,202
# Trainable params: 1,904,202
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit_generator(
        training_data,
        steps_per_epoch=312,
        epochs=12,
        validation_data=testing_data,
        validation_steps=30)
# Out:
# <ipython-input-48-38860f45d7f9>:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# Epoch 1/12
# 312/312 [==============================] - 15s 47ms/step - loss: 1.8989 - acc: 0.2884 - val_loss: 1.5993 - val_acc: 0.4031
# Epoch 2/12
# 312/312 [==============================] - 16s 50ms/step - loss: 1.3060 - acc: 0.5265 - val_loss: 1.4953 - val_acc: 0.4938
# Epoch 3/12
# 312/312 [==============================] - 14s 44ms/step - loss: 1.0273 - acc: 0.6269 - val_loss: 1.1964 - val_acc: 0.6094
# Epoch 4/12
# 312/312 [==============================] - 15s 47ms/step - loss: 0.8780 - acc: 0.6855 - val_loss: 1.2784 - val_acc: 0.6062
# Epoch 5/12
# 312/312 [==============================] - 25s 81ms/step - loss: 0.7564 - acc: 0.7260 - val_loss: 0.7851 - val_acc: 0.7240
# Epoch 6/12
# 312/312 [==============================] - 14s 46ms/step - loss: 0.6859 - acc: 0.7570 - val_loss: 0.8702 - val_acc: 0.6990
# Epoch 7/12
# 312/312 [==============================] - 13s 42ms/step - loss: 0.6113 - acc: 0.7825 - val_loss: 0.7670 - val_acc: 0.7375
# Epoch 8/12
# 312/312 [==============================] - 13s 42ms/step - loss: 0.6010 - acc: 0.7888 - val_loss: 0.9335 - val_acc: 0.6719
# Epoch 9/12
# 312/312 [==============================] - 13s 42ms/step - loss: 0.5365 - acc: 0.8048 - val_loss: 1.0624 - val_acc: 0.6698
# Epoch 10/12
# 312/312 [==============================] - 14s 43ms/step - loss: 0.5218 - acc: 0.8146 - val_loss: 0.8894 - val_acc: 0.7146
# Epoch 11/12
# 312/312 [==============================] - 14s 44ms/step - loss: 0.4724 - acc: 0.8333 - val_loss: 1.1251 - val_acc: 0.6698
# Epoch 12/12
# 312/312 [==============================] - 14s 44ms/step - loss: 0.4579 - acc: 0.8414 - val_loss: 0.8428 - val_acc: 0.7417

# %%
import matplotlib.pyplot as plt
acc_original=history.history["acc"]
val_acc_original=history.history["val_acc"]
loss_original=history.history["loss"]
val_loss_original=history.history["val_loss"]

epochs=range(1,len(acc_original)+1)
val_epochs=range(1,len(val_acc_original)+1)


sizeplt=plt.figure()
sizeplt.set_figwidth(16)
sizeplt.set_figheight(6)

plt.plot(epochs,acc_original,'mo',label="Eğitim başarımı(original)")
plt.plot(val_epochs,val_acc_original,'m--',label="Doğrulama başarımı(original)")
plt.title("Eğitim ve Doğrulama başarımı")
plt.legend()
plt.figure()


sizeplt=plt.figure()
sizeplt.set_figwidth(16)
sizeplt.set_figheight(6)

plt.plot(epochs,loss_original,'ko',label="Eğitim kaybı(original)")
plt.plot(val_epochs,val_loss_original,'m--',label="Doğrulama kaybı(original)")
plt.title("Eğitim ve Doğrulama kaybı")
plt.legend()

plt.show()

# %%
print("Adam")
# Out:
# Adam

# %%
# model

from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Dropout

model = Sequential()
model.add(Conv2D(64,(3,3),activation="relu", input_shape =(image_size,image_size,3)))
model.add(Conv2D(64,(3,3),activation="relu"))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128,(3,3),activation="relu"))
model.add(Conv2D(128,(3,3),activation="relu"))
model.add(MaxPooling2D(2,2))


model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(512,activation = "relu"))
model.add(Dense(10,activation = "softmax"))

model.compile(optimizer="RMSprop",loss="categorical_crossentropy",metrics=["acc"])

model.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_60 (Conv2D)          (None, 30, 30, 64)        1792
#
#  conv2d_61 (Conv2D)          (None, 28, 28, 64)        36928
#
#  max_pooling2d_31 (MaxPoolin  (None, 14, 14, 64)       0
#  g2D)
#
#  conv2d_62 (Conv2D)          (None, 12, 12, 128)       73856
#
#  conv2d_63 (Conv2D)          (None, 10, 10, 128)       147584
#
#  max_pooling2d_32 (MaxPoolin  (None, 5, 5, 128)        0
#  g2D)
#
#  flatten_15 (Flatten)        (None, 3200)              0
#
#  dropout_15 (Dropout)        (None, 3200)              0
#
#  dense_31 (Dense)            (None, 512)               1638912
#
#  dense_32 (Dense)            (None, 10)                5130
#
# =================================================================
# Total params: 1,904,202
# Trainable params: 1,904,202
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit_generator(
        training_data,
        steps_per_epoch=312,
        epochs=12,
        validation_data=testing_data,
        validation_steps=30)
# Out:
# Epoch 1/12
# <ipython-input-52-38860f45d7f9>:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# 312/312 [==============================] - 15s 45ms/step - loss: 1.9673 - acc: 0.2843 - val_loss: 1.7113 - val_acc: 0.3760
# Epoch 2/12
# 312/312 [==============================] - 14s 45ms/step - loss: 1.4210 - acc: 0.5011 - val_loss: 0.9376 - val_acc: 0.6625
# Epoch 3/12
# 312/312 [==============================] - 14s 44ms/step - loss: 1.1381 - acc: 0.6107 - val_loss: 0.9789 - val_acc: 0.6781
# Epoch 4/12
# 312/312 [==============================] - 14s 44ms/step - loss: 0.9928 - acc: 0.6588 - val_loss: 1.0163 - val_acc: 0.6625
# Epoch 5/12
# 312/312 [==============================] - 14s 45ms/step - loss: 0.8625 - acc: 0.7099 - val_loss: 0.7659 - val_acc: 0.7594
# Epoch 6/12
# 312/312 [==============================] - 30s 97ms/step - loss: 0.7766 - acc: 0.7322 - val_loss: 0.8360 - val_acc: 0.7427
# Epoch 7/12
# 312/312 [==============================] - 27s 87ms/step - loss: 0.7197 - acc: 0.7551 - val_loss: 1.0518 - val_acc: 0.7448
# Epoch 8/12
# 312/312 [==============================] - 22s 71ms/step - loss: 0.6728 - acc: 0.7692 - val_loss: 0.8360 - val_acc: 0.7552
# Epoch 9/12
# 312/312 [==============================] - 14s 45ms/step - loss: 0.6341 - acc: 0.7899 - val_loss: 0.7828 - val_acc: 0.7740
# Epoch 10/12
# 312/312 [==============================] - 14s 46ms/step - loss: 0.6201 - acc: 0.7938 - val_loss: 0.7281 - val_acc: 0.7750
# Epoch 11/12
# 312/312 [==============================] - 14s 44ms/step - loss: 0.6018 - acc: 0.7982 - val_loss: 1.0734 - val_acc: 0.7000
# Epoch 12/12
# 312/312 [==============================] - 14s 44ms/step - loss: 0.5859 - acc: 0.8123 - val_loss: 0.7012 - val_acc: 0.7823

# %%
import matplotlib.pyplot as plt
acc_original=history.history["acc"]
val_acc_original=history.history["val_acc"]
loss_original=history.history["loss"]
val_loss_original=history.history["val_loss"]

epochs=range(1,len(acc_original)+1)
val_epochs=range(1,len(val_acc_original)+1)


sizeplt=plt.figure()
sizeplt.set_figwidth(16)
sizeplt.set_figheight(6)

plt.plot(epochs,acc_original,'mo',label="Eğitim başarımı(original)")
plt.plot(val_epochs,val_acc_original,'m--',label="Doğrulama başarımı(original)")
plt.title("Eğitim ve Doğrulama başarımı")
plt.legend()
plt.figure()


sizeplt=plt.figure()
sizeplt.set_figwidth(16)
sizeplt.set_figheight(6)

plt.plot(epochs,loss_original,'ko',label="Eğitim kaybı(original)")
plt.plot(val_epochs,val_loss_original,'m--',label="Doğrulama kaybı(original)")
plt.title("Eğitim ve Doğrulama kaybı")
plt.legend()

plt.show()

# %%
print("RMSprop")
# Out:
# RMSprop

# %%
# model

from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Dropout

model = Sequential()
model.add(Conv2D(64,(3,3),activation="tanh", input_shape =(image_size,image_size,3)))
model.add(Conv2D(64,(3,3),activation="tanh"))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128,(3,3),activation="tanh"))
model.add(Conv2D(128,(3,3),activation="tanh"))
model.add(MaxPooling2D(2,2))


model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(512,activation = "tanh"))
model.add(Dense(10,activation = "softmax"))

model.compile(optimizer="Adam",loss="categorical_crossentropy",metrics=["acc"])

model.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_64 (Conv2D)          (None, 30, 30, 64)        1792
#
#  conv2d_65 (Conv2D)          (None, 28, 28, 64)        36928
#
#  max_pooling2d_33 (MaxPoolin  (None, 14, 14, 64)       0
#  g2D)
#
#  conv2d_66 (Conv2D)          (None, 12, 12, 128)       73856
#
#  conv2d_67 (Conv2D)          (None, 10, 10, 128)       147584
#
#  max_pooling2d_34 (MaxPoolin  (None, 5, 5, 128)        0
#  g2D)
#
#  flatten_16 (Flatten)        (None, 3200)              0
#
#  dropout_16 (Dropout)        (None, 3200)              0
#
#  dense_33 (Dense)            (None, 512)               1638912
#
#  dense_34 (Dense)            (None, 10)                5130
#
# =================================================================
# Total params: 1,904,202
# Trainable params: 1,904,202
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit_generator(
        training_data,
        steps_per_epoch=312,
        epochs=12,
        validation_data=testing_data,
        validation_steps=30)
# Out:
# Epoch 1/12
# <ipython-input-56-38860f45d7f9>:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# 312/312 [==============================] - 19s 57ms/step - loss: 1.8000 - acc: 0.3757 - val_loss: 2.3227 - val_acc: 0.3729
# Epoch 2/12
# 312/312 [==============================] - 17s 54ms/step - loss: 1.4086 - acc: 0.5074 - val_loss: 2.9945 - val_acc: 0.2948
# Epoch 3/12
# 312/312 [==============================] - 17s 55ms/step - loss: 1.1602 - acc: 0.5875 - val_loss: 2.1185 - val_acc: 0.4156
# Epoch 4/12
# 312/312 [==============================] - 17s 53ms/step - loss: 1.0401 - acc: 0.6304 - val_loss: 1.3814 - val_acc: 0.5344
# Epoch 5/12
# 312/312 [==============================] - 13s 43ms/step - loss: 0.8990 - acc: 0.6818 - val_loss: 1.1797 - val_acc: 0.5979
# Epoch 6/12
# 312/312 [==============================] - 20s 63ms/step - loss: 0.8387 - acc: 0.6975 - val_loss: 1.1670 - val_acc: 0.6073
# Epoch 7/12
# 312/312 [==============================] - 14s 45ms/step - loss: 0.7943 - acc: 0.7139 - val_loss: 1.4987 - val_acc: 0.5135
# Epoch 8/12
# 312/312 [==============================] - 14s 44ms/step - loss: 0.7840 - acc: 0.7155 - val_loss: 1.0542 - val_acc: 0.6396
# Epoch 9/12
# 312/312 [==============================] - 14s 44ms/step - loss: 0.7659 - acc: 0.7297 - val_loss: 1.1863 - val_acc: 0.6177
# Epoch 10/12
# 312/312 [==============================] - 17s 53ms/step - loss: 0.7091 - acc: 0.7517 - val_loss: 1.2455 - val_acc: 0.6042
# Epoch 11/12
# 312/312 [==============================] - 21s 66ms/step - loss: 0.7320 - acc: 0.7425 - val_loss: 1.2466 - val_acc: 0.6021
# Epoch 12/12
# 312/312 [==============================] - 15s 47ms/step - loss: 0.6934 - acc: 0.7499 - val_loss: 1.1365 - val_acc: 0.6146

# %%
print("Adam and tanh")
# Out:
# Adam and tanh

# %%
# model

from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Dropout

model = Sequential()
model.add(Conv2D(64,(3,3),activation="tanh", input_shape =(image_size,image_size,3)))
model.add(Conv2D(64,(3,3),activation="tanh"))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128,(3,3),activation="tanh"))
model.add(Conv2D(128,(3,3),activation="tanh"))
model.add(MaxPooling2D(2,2))


model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(512,activation = "tanh"))
model.add(Dense(10,activation = "softmax"))

model.compile(optimizer="RMSprop",loss="categorical_crossentropy",metrics=["acc"])

model.summary()
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_68 (Conv2D)          (None, 30, 30, 64)        1792
#
#  conv2d_69 (Conv2D)          (None, 28, 28, 64)        36928
#
#  max_pooling2d_35 (MaxPoolin  (None, 14, 14, 64)       0
#  g2D)
#
#  conv2d_70 (Conv2D)          (None, 12, 12, 128)       73856
#
#  conv2d_71 (Conv2D)          (None, 10, 10, 128)       147584
#
#  max_pooling2d_36 (MaxPoolin  (None, 5, 5, 128)        0
#  g2D)
#
#  flatten_17 (Flatten)        (None, 3200)              0
#
#  dropout_17 (Dropout)        (None, 3200)              0
#
#  dense_35 (Dense)            (None, 512)               1638912
#
#  dense_36 (Dense)            (None, 10)                5130
#
# =================================================================
# Total params: 1,904,202
# Trainable params: 1,904,202
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit_generator(
        training_data,
        steps_per_epoch=312,
        epochs=12,
        validation_data=testing_data,
        validation_steps=30)
# Out:
# Epoch 1/12
# <ipython-input-59-38860f45d7f9>:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# 312/312 [==============================] - 17s 51ms/step - loss: 2.6069 - acc: 0.1025 - val_loss: 2.3982 - val_acc: 0.1042
# Epoch 2/12
# 312/312 [==============================] - 15s 49ms/step - loss: 2.3911 - acc: 0.1066 - val_loss: 2.4371 - val_acc: 0.1052
# Epoch 3/12
# 312/312 [==============================] - 14s 43ms/step - loss: 2.4030 - acc: 0.1108 - val_loss: 2.3968 - val_acc: 0.0979
# Epoch 4/12
# 312/312 [==============================] - 13s 43ms/step - loss: 2.3916 - acc: 0.1007 - val_loss: 2.4679 - val_acc: 0.0979
# Epoch 5/12
# 312/312 [==============================] - 13s 43ms/step - loss: 2.3883 - acc: 0.0987 - val_loss: 2.4087 - val_acc: 0.1000
# Epoch 6/12
# 312/312 [==============================] - 13s 43ms/step - loss: 2.3857 - acc: 0.1069 - val_loss: 2.4615 - val_acc: 0.1021
# Epoch 7/12
# 312/312 [==============================] - 13s 43ms/step - loss: 2.3888 - acc: 0.0999 - val_loss: 2.3827 - val_acc: 0.1000
# Epoch 8/12
# 312/312 [==============================] - 14s 44ms/step - loss: 2.3911 - acc: 0.0988 - val_loss: 2.3312 - val_acc: 0.0990
# Epoch 9/12
# 312/312 [==============================] - 15s 46ms/step - loss: 2.3887 - acc: 0.0978 - val_loss: 2.4191 - val_acc: 0.1000
# Epoch 10/12
# 312/312 [==============================] - 16s 51ms/step - loss: 2.3904 - acc: 0.1030 - val_loss: 2.3516 - val_acc: 0.0979
# Epoch 11/12
# 312/312 [==============================] - 13s 42ms/step - loss: 2.3865 - acc: 0.0980 - val_loss: 2.3614 - val_acc: 0.1010
# Epoch 12/12
# 312/312 [==============================] - 13s 42ms/step - loss: 2.3857 - acc: 0.1003 - val_loss: 2.4379 - val_acc: 0.1010

# %%
print("RMSprop and tanh")
# Out:
# RMSprop and tanh

# %%
import matplotlib.pyplot as plt
acc_original=history.history["acc"]
val_acc_original=history.history["val_acc"]
loss_original=history.history["loss"]
val_loss_original=history.history["val_loss"]

epochs=range(1,len(acc_original)+1)
val_epochs=range(1,len(val_acc_original)+1)


sizeplt=plt.figure()
sizeplt.set_figwidth(16)
sizeplt.set_figheight(6)

plt.plot(epochs,acc_original,'mo',label="Eğitim başarımı(original)")
plt.plot(val_epochs,val_acc_original,'m--',label="Doğrulama başarımı(original)")
plt.title("Eğitim ve Doğrulama başarımı")
plt.legend()
plt.figure()


sizeplt=plt.figure()
sizeplt.set_figwidth(16)
sizeplt.set_figheight(6)

plt.plot(epochs,loss_original,'ko',label="Eğitim kaybı(original)")
plt.plot(val_epochs,val_loss_original,'m--',label="Doğrulama kaybı(original)")
plt.title("Eğitim ve Doğrulama kaybı")
plt.legend()

plt.show()

# %%
# model

from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Dropout

model = Sequential()
model.add(Conv2D(64,(3,3),activation="tanh", input_shape =(image_size,image_size,3)))
model.add(Conv2D(64,(3,3),activation="tanh"))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128,(3,3),activation="tanh"))
model.add(Conv2D(128,(3,3),activation="tanh"))
model.add(MaxPooling2D(2,2))


model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(512,activation = "tanh"))
model.add(Dense(10,activation = "softmax"))

model.compile(optimizer="Adam",loss="categorical_crossentropy",metrics=["acc"])

model.summary()
# Out:
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_72 (Conv2D)          (None, 30, 30, 64)        1792
#
#  conv2d_73 (Conv2D)          (None, 28, 28, 64)        36928
#
#  max_pooling2d_37 (MaxPoolin  (None, 14, 14, 64)       0
#  g2D)
#
#  conv2d_74 (Conv2D)          (None, 12, 12, 128)       73856
#
#  conv2d_75 (Conv2D)          (None, 10, 10, 128)       147584
#
#  max_pooling2d_38 (MaxPoolin  (None, 5, 5, 128)        0
#  g2D)
#
#  flatten_18 (Flatten)        (None, 3200)              0
#
#  dropout_18 (Dropout)        (None, 3200)              0
#
#  dense_37 (Dense)            (None, 512)               1638912
#
#  dense_38 (Dense)            (None, 10)                5130
#
# =================================================================
# Total params: 1,904,202
# Trainable params: 1,904,202
# Non-trainable params: 0
# _________________________________________________________________

# %%
print("Adam and tanh")
# Out:
# Adam and tanh

# %%
history = model.fit_generator(
        training_data,
        steps_per_epoch=312,
        epochs=12,
        validation_data=testing_data,
        validation_steps=30)
# Out:
# Epoch 1/12
# <ipython-input-64-38860f45d7f9>:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# 312/312 [==============================] - 14s 42ms/step - loss: 1.8598 - acc: 0.3528 - val_loss: 1.9387 - val_acc: 0.3896
# Epoch 2/12
# 312/312 [==============================] - 13s 42ms/step - loss: 1.4246 - acc: 0.5049 - val_loss: 1.8101 - val_acc: 0.4115
# Epoch 3/12
# 312/312 [==============================] - 15s 47ms/step - loss: 1.1896 - acc: 0.5822 - val_loss: 1.5235 - val_acc: 0.4833
# Epoch 4/12
# 312/312 [==============================] - 15s 48ms/step - loss: 0.9889 - acc: 0.6504 - val_loss: 1.2033 - val_acc: 0.5729
# Epoch 5/12
# 312/312 [==============================] - 18s 59ms/step - loss: 0.8841 - acc: 0.6896 - val_loss: 1.6268 - val_acc: 0.5302
# Epoch 6/12
# 312/312 [==============================] - 16s 51ms/step - loss: 0.8135 - acc: 0.7093 - val_loss: 1.0028 - val_acc: 0.6542
# Epoch 7/12
# 312/312 [==============================] - 13s 41ms/step - loss: 0.7776 - acc: 0.7235 - val_loss: 1.3340 - val_acc: 0.5469
# Epoch 8/12
# 312/312 [==============================] - 13s 41ms/step - loss: 0.7729 - acc: 0.7290 - val_loss: 0.9054 - val_acc: 0.6938
# Epoch 9/12
# 312/312 [==============================] - 13s 43ms/step - loss: 0.7351 - acc: 0.7331 - val_loss: 1.3268 - val_acc: 0.5979
# Epoch 10/12
# 312/312 [==============================] - 15s 47ms/step - loss: 0.7303 - acc: 0.7377 - val_loss: 0.9739 - val_acc: 0.6698
# Epoch 11/12
# 312/312 [==============================] - 20s 65ms/step - loss: 0.6950 - acc: 0.7499 - val_loss: 0.8721 - val_acc: 0.7115
# Epoch 12/12
# 312/312 [==============================] - 14s 43ms/step - loss: 0.6634 - acc: 0.7610 - val_loss: 1.3339 - val_acc: 0.5990

# %%
import matplotlib.pyplot as plt
acc_original=history.history["acc"]
val_acc_original=history.history["val_acc"]
loss_original=history.history["loss"]
val_loss_original=history.history["val_loss"]

epochs=range(1,len(acc_original)+1)
val_epochs=range(1,len(val_acc_original)+1)


sizeplt=plt.figure()
sizeplt.set_figwidth(16)
sizeplt.set_figheight(6)

plt.plot(epochs,acc_original,'mo',label="Eğitim başarımı(original)")
plt.plot(val_epochs,val_acc_original,'m--',label="Doğrulama başarımı(original)")
plt.title("Eğitim ve Doğrulama başarımı")
plt.legend()
plt.figure()


sizeplt=plt.figure()
sizeplt.set_figwidth(16)
sizeplt.set_figheight(6)

plt.plot(epochs,loss_original,'ko',label="Eğitim kaybı(original)")
plt.plot(val_epochs,val_loss_original,'m--',label="Doğrulama kaybı(original)")
plt.title("Eğitim ve Doğrulama kaybı")
plt.legend()

plt.show()
